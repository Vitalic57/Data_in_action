# %% [markdown]
# ### Word2vec

# %% [markdown]
# Сегодня мы научимся работать с word2vec моделями. Загрузим и потестим предобученную, посмотрим, какие крутые свойства и функции у нее бывают, обучим свою модель и с помощью нее улучшим качество кластеризации(и/или классификации) текстов

# %% [markdown]
# Установим все необходимое

# %% [markdown]
# !pip3 install tqdm
# !pip3 install pymorphy2
# !pip3 install gensim
# !pip3 install sklearn
# !pip3 install pandas
# !pip3 install matplotlib

# %% [markdown]
# #### Скачаем rucorpora 15 с диска https://yadi.sk/d/fLRMFhm03Pbs98

# %%
# Прописываем путь до файла
#path_to_ruscorpora = <Ваш код>
path_to_ruscorpora = 'ruscorpora.model.bin'

# %% [markdown]
# Импортируем нужные библиотеки

# %%
from gensim.models import Word2Vec
import pandas as pd
from tqdm import tqdm
import gensim
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
# Out:
# C:\Users\Vitaly\Anaconda3\lib\site-packages\gensim\utils.py:860: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %% [markdown]
# Шапка для картинок

# %%
import matplotlib.pyplot as plt
# для встроенных картинок
# %pylab inline
# чуть покрасивше картинки:
plt.style.use('default')
figsize(12, 9)

import warnings
warnings.filterwarnings("ignore")

#plt.rcParams['figure.figsize'] = 10, 7.5
#plt.rcParams['axes.grid'] = True
pd.set_option('display.max_columns', None)


import matplotlib as mpl
mpl.rcParams['font.family'] = 'Ubuntu'

plt.rc('text', usetex=False)
plt.rc('font', family='serif')
plt.rc('font', weight='bold')
plt.rc('xtick', labelsize=14) 
plt.rc('ytick', labelsize=14)

# чтобы был русский шрифт
from matplotlib import rc
 
font = {'family': 'Verdana',
        'weight': 'normal'}
rc('font', **font)# для встроенных картинок
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Сначала познакомимся с уже готовой реализацией word2vec на gensim

# %% [markdown]
# #### Загрузим обученную на ruscorpora модель word2vec

# %%
model_word2vec = gensim.models.KeyedVectors.load_word2vec_format(path_to_ruscorpora, binary = True)

# %%
model_word2vec.wv.vocab
# Out:
# {'нарусова': <gensim.models.keyedvectors.Vocab at 0x1577a75bf28>,
#  'ветреничать': <gensim.models.keyedvectors.Vocab at 0x1571cb675f8>,
#  'малко': <gensim.models.keyedvectors.Vocab at 0x157208523c8>,
#  'карб': <gensim.models.keyedvectors.Vocab at 0x1577ccfd8d0>,
#  'зубчатка': <gensim.models.keyedvectors.Vocab at 0x1577a3d7c88>,
#  'тонкошеий': <gensim.models.keyedvectors.Vocab at 0x1577a5897f0>,
#  'вигский': <gensim.models.keyedvectors.Vocab at 0x1571cc76278>,
#  'зыкова': <gensim.models.keyedvectors.Vocab at 0x1577cbc3828>,
#  'сисин': <gensim.models.keyedvectors.Vocab at 0x1577f8ec2b0>,
#  'петрушенко': <gensim.models.keyedvectors.Vocab at 0x1577c5b3908>,
#  'погонин': <gensim.models.keyedvectors.Vocab at 0x1577aa89d30>,
#  'постимпрессионист': <gensim.models.keyedvectors.Vocab at 0x1577c630518>,
#  'цезарь': <gensim.models.keyedvectors.Vocab at 0x15777ed0828>,
#  'nt': <gensim.models.keyedvectors.Vocab at 0x1577a1e4c18>,
#  'наддавать': <gensim.models.keyedvectors.Vocab at 0x15779959208>,
#  'карябать': <gensim.models.keyedvectors.Vocab at 0x1577c3bc4a8>,
#  'bovis': <gensim.models.keyedvectors.Vocab at 0x15720570550>,
#  'опечь': <gensim.models.keyedvectors.Vocab at 0x1577f561080>,
#  'вдвигаться': <gensim.models.keyedvectors.Vocab at 0x157782c1e80>,
#  'сулейманович': <gensim.models.keyedvectors.Vocab at 0x1577c6670f0>,
#  'шпинька': <gensim.models.keyedvectors.Vocab at 0x1577fa0a550>,
#  'айзенштейн': <gensim.models.keyedvectors.Vocab at 0x1577c2213c8>,
#  'моторизация': <gensim.models.keyedvectors.Vocab at 0x1577cbd64e0>,
#  'фауссек': <gensim.models.keyedvectors.Vocab at 0x1571c8ee048>,
#  'междуножье': <gensim.models.keyedvectors.Vocab at 0x1571bc90320>,
#  'саханыч': <gensim.models.keyedvectors.Vocab at 0x1577ca57240>,
#  'казнити': <gensim.models.keyedvectors.Vocab at 0x1577e2b80b8>,
#  'толченов': <gensim.models.keyedvectors.Vocab at 0x1577c4534a8>,
#  'гидрошикап': <gensim.models.keyedvectors.Vocab at 0x1571e6e1f98>,
#  'цурикова': <gensim.models.keyedvectors.Vocab at 0x1571e6150b8>,
#  'ончик': <gensim.models.keyedvectors.Vocab at 0x15779afa898>,
#  'неоноподобный': <gensim.models.keyedvectors.Vocab at 0x1577fae3470>,
#  'сатюков': <gensim.models.keyedvectors.Vocab at 0x1577f6c8710>,
#  'фюнить': <gensim.models.keyedvectors.Vocab at 0x1571cbdca20>,
#  'эгоистично': <gensim.models.keyedvectors.Vocab at 0x1577a14ce48>,
#  'sportwagon': <gensim.models.keyedvectors.Vocab at 0x1577f5f26d8>,
#  'выкапываться': <gensim.models.keyedvectors.Vocab at 0x1577a697278>,
#  'колодязьский': <gensim.models.keyedvectors.Vocab at 0x1571ca31358>,
#  'взмах': <gensim.models.keyedvectors.Vocab at 0x15777f39fd0>,
#  'полуреально': <gensim.models.keyedvectors.Vocab at 0x1571e322588>,
#  'тоюй': <gensim.models.keyedvectors.Vocab at 0x1571c97c5f8>,
#  'мизон': <gensim.models.keyedvectors.Vocab at 0x1577ccd1630>,
#  'подтоварье': <gensim.models.keyedvectors.Vocab at 0x1571c68e518>,
#  'annonce': <gensim.models.keyedvectors.Vocab at 0x1571e637d30>,
#  'зойдись': <gensim.models.keyedvectors.Vocab at 0x1571c7b7048>,
#  'осиевский': <gensim.models.keyedvectors.Vocab at 0x1577a83b208>,
#  'капитанский': <gensim.models.keyedvectors.Vocab at 0x15778011320>,
#  'обделочный': <gensim.models.keyedvectors.Vocab at 0x1571c667b38>,
#  'паное': <gensim.models.keyedvectors.Vocab at 0x1577e563c88>,
#  'прелюбезно': <gensim.models.keyedvectors.Vocab at 0x1571bf754e0>,
#  'аксель': <gensim.models.keyedvectors.Vocab at 0x157796f89e8>,
#  'коалиционист': <gensim.models.keyedvectors.Vocab at 0x1577a8694e0>,
#  'инстед': <gensim.models.keyedvectors.Vocab at 0x1571e38f390>,
#  'тейпово': <gensim.models.keyedvectors.Vocab at 0x1577bfaebe0>,
#  'гилялович': <gensim.models.keyedvectors.Vocab at 0x1571bdd34e0>,
#  'верховище': <gensim.models.keyedvectors.Vocab at 0x1571e5d6828>,
#  'сверхбиологический': <gensim.models.keyedvectors.Vocab at 0x1571bd05198>,
#  'осьминка': <gensim.models.keyedvectors.Vocab at 0x1571ccb2b70>,
#  'фалеев': <gensim.models.keyedvectors.Vocab at 0x15779d78198>,
#  'киноколосс': <gensim.models.keyedvectors.Vocab at 0x1571e4501d0>,
#  'воскуриваться': <gensim.models.keyedvectors.Vocab at 0x1571c54b9b0>,
#  'бух': <gensim.models.keyedvectors.Vocab at 0x157785de0b8>,
#  'цитриняк': <gensim.models.keyedvectors.Vocab at 0x1577cce15c0>,
#  'хемопсин': <gensim.models.keyedvectors.Vocab at 0x1577ff3b5f8>,
#  'беломорчик': <gensim.models.keyedvectors.Vocab at 0x1571e6baf98>,
#  'пересол': <gensim.models.keyedvectors.Vocab at 0x1577c5b8a90>,
#  'клекать': <gensim.models.keyedvectors.Vocab at 0x1571e72ec88>,
#  'сахур': <gensim.models.keyedvectors.Vocab at 0x1577c740438>,
#  'тошновато': <gensim.models.keyedvectors.Vocab at 0x1571c652b70>,
#  'лиатриса': <gensim.models.keyedvectors.Vocab at 0x1577e1a9278>,
#  'белинский': <gensim.models.keyedvectors.Vocab at 0x15777e865f8>,
#  'деловар': <gensim.models.keyedvectors.Vocab at 0x1577caef240>,
#  'петмол': <gensim.models.keyedvectors.Vocab at 0x1577c404128>,
#  'метракомбанк': <gensim.models.keyedvectors.Vocab at 0x1571be6ac50>,
#  'пыталово': <gensim.models.keyedvectors.Vocab at 0x1577c7fc5c0>,
#  'отягощать': <gensim.models.keyedvectors.Vocab at 0x15778152ba8>,
#  'веялис': <gensim.models.keyedvectors.Vocab at 0x1571c3d7240>,
#  'повелич': <gensim.models.keyedvectors.Vocab at 0x15721b645f8>,
#  'гогеновский': <gensim.models.keyedvectors.Vocab at 0x1577adfcac8>,
#  'фракасторо': <gensim.models.keyedvectors.Vocab at 0x1577a5bf0f0>,
#  'гриль-бар': <gensim.models.keyedvectors.Vocab at 0x1577aa82a90>,
#  'псс': <gensim.models.keyedvectors.Vocab at 0x15779dd5c88>,
#  'первородство': <gensim.models.keyedvectors.Vocab at 0x15778379860>,
#  'шизоидия': <gensim.models.keyedvectors.Vocab at 0x1577adf3470>,
#  'жувен': <gensim.models.keyedvectors.Vocab at 0x157219b51d0>,
#  'кумарин': <gensim.models.keyedvectors.Vocab at 0x1577c322710>,
#  'диордиев': <gensim.models.keyedvectors.Vocab at 0x157205d8550>,
#  'шинбет': <gensim.models.keyedvectors.Vocab at 0x15721ab75f8>,
#  'хлеб': <gensim.models.keyedvectors.Vocab at 0x15777c4b550>,
#  'самозахват': <gensim.models.keyedvectors.Vocab at 0x1577bfeac18>,
#  'хилак': <gensim.models.keyedvectors.Vocab at 0x1577c6a7828>,
#  'зюков': <gensim.models.keyedvectors.Vocab at 0x1577aaf5390>,
#  'трикетогидринден': <gensim.models.keyedvectors.Vocab at 0x1577cb78198>,
#  'венчинов': <gensim.models.keyedvectors.Vocab at 0x1571e4b9588>,
#  'тремейн': <gensim.models.keyedvectors.Vocab at 0x1571c8b9e10>,
#  'микитов': <gensim.models.keyedvectors.Vocab at 0x1577a5d5b00>,
#  'фатический': <gensim.models.keyedvectors.Vocab at 0x1572067fb38>,
#  'бутиллитий': <gensim.models.keyedvectors.Vocab at 0x1577cfe3780>,
#  'объятный': <gensim.models.keyedvectors.Vocab at 0x1571e156be0>,
#  'теллурический': <gensim.models.keyedvectors.Vocab at 0x1577c3e8b00>,
#  'голубин': <gensim.models.keyedvectors.Vocab at 0x1577a1fd780>,
#  'шамсеев': <gensim.models.keyedvectors.Vocab at 0x1571ebf2048>,
#  'нощеденствие': <gensim.models.keyedvectors.Vocab at 0x1571e6c4c50>,
#  'айкар': <gensim.models.keyedvectors.Vocab at 0x1577a78d240>,
#  'сякинский': <gensim.models.keyedvectors.Vocab at 0x1571ebe5fd0>,
#  'турово': <gensim.models.keyedvectors.Vocab at 0x1571e354978>,
#  'осеребрить': <gensim.models.keyedvectors.Vocab at 0x1577c564240>,
#  'крючочек': <gensim.models.keyedvectors.Vocab at 0x157782eb5c0>,
#  'иерархия': <gensim.models.keyedvectors.Vocab at 0x15777e14f28>,
#  'летна': <gensim.models.keyedvectors.Vocab at 0x1571c5f59b0>,
#  'рыхлиться': <gensim.models.keyedvectors.Vocab at 0x1571be55358>,
#  'метнев': <gensim.models.keyedvectors.Vocab at 0x1577f41c2e8>,
#  'левитановский': <gensim.models.keyedvectors.Vocab at 0x15779b2d128>,
#  'вриндаван': <gensim.models.keyedvectors.Vocab at 0x1577e4b1668>,
#  'хелатированный': <gensim.models.keyedvectors.Vocab at 0x1571c43aeb8>,
#  'спт': <gensim.models.keyedvectors.Vocab at 0x1577c2e24e0>,
#  'непродвинуть': <gensim.models.keyedvectors.Vocab at 0x1571c2cce80>,
#  'саламовый': <gensim.models.keyedvectors.Vocab at 0x1577ffbd160>,
#  'кроль': <gensim.models.keyedvectors.Vocab at 0x1577863e4a8>,
#  'завацкий': <gensim.models.keyedvectors.Vocab at 0x1577cecb128>,
#  'мартынушка': <gensim.models.keyedvectors.Vocab at 0x1577d16d438>,
#  'догрузка': <gensim.models.keyedvectors.Vocab at 0x1577e25f080>,
#  'беспартийщина': <gensim.models.keyedvectors.Vocab at 0x1571c9d1080>,
#  'всевечный': <gensim.models.keyedvectors.Vocab at 0x1571ccb70b8>,
#  'гройверный': <gensim.models.keyedvectors.Vocab at 0x1571e5f3e80>,
#  'стоход': <gensim.models.keyedvectors.Vocab at 0x1577a2e12e8>,
#  'кантонист': <gensim.models.keyedvectors.Vocab at 0x157782f32e8>,
#  'мецкий': <gensim.models.keyedvectors.Vocab at 0x1571cc55898>,
#  'prosperity': <gensim.models.keyedvectors.Vocab at 0x1577f921278>,
#  'видет': <gensim.models.keyedvectors.Vocab at 0x1577ab2c128>,
#  'протопопица': <gensim.models.keyedvectors.Vocab at 0x1577cb2f2b0>,
#  'гашун': <gensim.models.keyedvectors.Vocab at 0x1577c5e09e8>,
#  'пухляк': <gensim.models.keyedvectors.Vocab at 0x1577ca60e80>,
#  'тимурленга': <gensim.models.keyedvectors.Vocab at 0x1571e29b278>,
#  'вожделевать': <gensim.models.keyedvectors.Vocab at 0x1577f62d0f0>,
#  'самокатегоризация': <gensim.models.keyedvectors.Vocab at 0x1577ae11358>,
#  'термочувствительный': <gensim.models.keyedvectors.Vocab at 0x1577e2412b0>,
#  'предприятие': <gensim.models.keyedvectors.Vocab at 0x15777c3d2e8>,
#  'антисоциализм': <gensim.models.keyedvectors.Vocab at 0x1571c436400>,
#  'медленно': <gensim.models.keyedvectors.Vocab at 0x15777c4bd68>,
#  'улюлюкать': <gensim.models.keyedvectors.Vocab at 0x157799fa6a0>,
#  'капелько': <gensim.models.keyedvectors.Vocab at 0x1571e241240>,
#  'филосемитизм': <gensim.models.keyedvectors.Vocab at 0x1577f882048>,
#  'кенигсвальд': <gensim.models.keyedvectors.Vocab at 0x1571c1b8be0>,
#  'курганный': <gensim.models.keyedvectors.Vocab at 0x15779a1d5f8>,
#  'епихина': <gensim.models.keyedvectors.Vocab at 0x1571e1109b0>,
#  'возь': <gensim.models.keyedvectors.Vocab at 0x1571df18f98>,
#  'чепляться': <gensim.models.keyedvectors.Vocab at 0x1577fb3aef0>,
#  'пасть': <gensim.models.keyedvectors.Vocab at 0x15777cd8940>,
#  'тифос': <gensim.models.keyedvectors.Vocab at 0x1571cbe02b0>,
#  'пер': <gensim.models.keyedvectors.Vocab at 0x15778221358>,
#  'вейскгражданстрой': <gensim.models.keyedvectors.Vocab at 0x1571c604198>,
#  'pudendum': <gensim.models.keyedvectors.Vocab at 0x1577ccd9e10>,
#  'гаитянин': <gensim.models.keyedvectors.Vocab at 0x1577a3c4b38>,
#  'метчик': <gensim.models.keyedvectors.Vocab at 0x15779cce5f8>,
#  'наиня': <gensim.models.keyedvectors.Vocab at 0x1577bfd15f8>,
#  'тулузский': <gensim.models.keyedvectors.Vocab at 0x15779a96da0>,
#  'шегардзонг': <gensim.models.keyedvectors.Vocab at 0x1571c2be080>,
#  'divi': <gensim.models.keyedvectors.Vocab at 0x1577ab7e2e8>,
#  'бриджтаун': <gensim.models.keyedvectors.Vocab at 0x1571e731ac8>,
#  'черепичатый': <gensim.models.keyedvectors.Vocab at 0x1571be01390>,
#  'внеопытный': <gensim.models.keyedvectors.Vocab at 0x1577c218f60>,
#  'клушина': <gensim.models.keyedvectors.Vocab at 0x1577e4e9588>,
#  'неперекрещенный': <gensim.models.keyedvectors.Vocab at 0x1571c3d7080>,
#  'восьмитысячник': <gensim.models.keyedvectors.Vocab at 0x1577c4311d0>,
#  'ревер': <gensim.models.keyedvectors.Vocab at 0x1577cd8b828>,
#  'вассилокопулос': <gensim.models.keyedvectors.Vocab at 0x1577c85cdd8>,
#  'хухэй': <gensim.models.keyedvectors.Vocab at 0x1571e3665f8>,
#  'латунный': <gensim.models.keyedvectors.Vocab at 0x15778275da0>,
#  'паштетный': <gensim.models.keyedvectors.Vocab at 0x1577d12dd68>,
#  'по-бурятски': <gensim.models.keyedvectors.Vocab at 0x1577c6b5b38>,
#  'яичко': <gensim.models.keyedvectors.Vocab at 0x15777feb780>,
#  'оплеушина': <gensim.models.keyedvectors.Vocab at 0x1577f215d30>,
#  'леленек': <gensim.models.keyedvectors.Vocab at 0x1571cc96d30>,
#  'менар': <gensim.models.keyedvectors.Vocab at 0x1577e482a20>,
#  'ora': <gensim.models.keyedvectors.Vocab at 0x1577c91a0b8>,
#  'шевардназда': <gensim.models.keyedvectors.Vocab at 0x1577f52d320>,
#  'винкель': <gensim.models.keyedvectors.Vocab at 0x1571c323470>,
#  'довля': <gensim.models.keyedvectors.Vocab at 0x1577ffe2208>,
#  'цниипромздание': <gensim.models.keyedvectors.Vocab at 0x1577e1c52b0>,
#  'cerevisiae': <gensim.models.keyedvectors.Vocab at 0x15779cc92b0>,
#  'линдерман': <gensim.models.keyedvectors.Vocab at 0x1577fb6f748>,
#  'германовский': <gensim.models.keyedvectors.Vocab at 0x1577e3a8b70>,
#  'мадеруцци': <gensim.models.keyedvectors.Vocab at 0x1577f895ba8>,
#  'науканский': <gensim.models.keyedvectors.Vocab at 0x1577bf02668>,
#  'фиренец': <gensim.models.keyedvectors.Vocab at 0x15721959940>,
#  'латынский': <gensim.models.keyedvectors.Vocab at 0x1577c258d30>,
#  'фредрикссон': <gensim.models.keyedvectors.Vocab at 0x1577e1b3b00>,
#  'синеблузый': <gensim.models.keyedvectors.Vocab at 0x1572073ae10>,
#  'volksstimme': <gensim.models.keyedvectors.Vocab at 0x1571c96ea58>,
#  'последышка': <gensim.models.keyedvectors.Vocab at 0x1571cc0c860>,
#  'задрочить': <gensim.models.keyedvectors.Vocab at 0x1577c05de10>,
#  'лежер': <gensim.models.keyedvectors.Vocab at 0x1577cfe3908>,
#  'бабуркин': <gensim.models.keyedvectors.Vocab at 0x1577ff800b8>,
#  'логвинович': <gensim.models.keyedvectors.Vocab at 0x1577e3142e8>,
#  'ревнивый': <gensim.models.keyedvectors.Vocab at 0x15777fb2438>,
#  'красков': <gensim.models.keyedvectors.Vocab at 0x1577c50deb8>,
#  'заволновать': <gensim.models.keyedvectors.Vocab at 0x1577cbaf358>,
#  'офеня': <gensim.models.keyedvectors.Vocab at 0x1577a202b70>,
#  'воздымут': <gensim.models.keyedvectors.Vocab at 0x1571cb59b38>,
#  'громогласный': <gensim.models.keyedvectors.Vocab at 0x157786bfac8>,
#  'кетхен': <gensim.models.keyedvectors.Vocab at 0x157219e07f0>,
#  'сейдюруш': <gensim.models.keyedvectors.Vocab at 0x1577f23ab00>,
#  'мысляев': <gensim.models.keyedvectors.Vocab at 0x1577a9f8898>,
#  'марен': <gensim.models.keyedvectors.Vocab at 0x1577a9c9f60>,
#  'славлянин': <gensim.models.keyedvectors.Vocab at 0x1571decfa20>,
#  'лысый': <gensim.models.keyedvectors.Vocab at 0x15777d904e0>,
#  'дитеныш': <gensim.models.keyedvectors.Vocab at 0x1577e185ba8>,
#  'куйбышевазот': <gensim.models.keyedvectors.Vocab at 0x1577a4cf320>,
#  'гигиенишвили': <gensim.models.keyedvectors.Vocab at 0x1577c471f98>,
#  'дидрахма': <gensim.models.keyedvectors.Vocab at 0x1577cac8588>,
#  'влскм': <gensim.models.keyedvectors.Vocab at 0x1571e2196d8>,
#  'рассклизнуть': <gensim.models.keyedvectors.Vocab at 0x1571bfd7518>,
#  'безголовый': <gensim.models.keyedvectors.Vocab at 0x157797fec18>,
#  'адаман': <gensim.models.keyedvectors.Vocab at 0x1577f5afb00>,
#  'джоэл': <gensim.models.keyedvectors.Vocab at 0x1577a546390>,
#  'тончавый': <gensim.models.keyedvectors.Vocab at 0x1571e515cc0>,
#  'энергосеть': <gensim.models.keyedvectors.Vocab at 0x1577cc35f98>,
#  'схватясти': <gensim.models.keyedvectors.Vocab at 0x1577c125f28>,
#  'абалаково': <gensim.models.keyedvectors.Vocab at 0x1577cfb8748>,
#  'dragic': <gensim.models.keyedvectors.Vocab at 0x1577f873978>,
#  'незатасканный': <gensim.models.keyedvectors.Vocab at 0x1577e1f1c18>,
#  'запрудер': <gensim.models.keyedvectors.Vocab at 0x1571ec5f828>,
#  'бамматов': <gensim.models.keyedvectors.Vocab at 0x1571de41358>,
#  'остроградский': <gensim.models.keyedvectors.Vocab at 0x15779a1dc18>,
#  'dооb': <gensim.models.keyedvectors.Vocab at 0x1571becdb38>,
#  'гомельск': <gensim.models.keyedvectors.Vocab at 0x1577ff67668>,
#  'безграничный': <gensim.models.keyedvectors.Vocab at 0x15777ebb668>,
#  'капустянский': <gensim.models.keyedvectors.Vocab at 0x1577cd8bd30>,
#  'коммендатор': <gensim.models.keyedvectors.Vocab at 0x1577a579fd0>,
#  'коневская': <gensim.models.keyedvectors.Vocab at 0x1577c0d0b00>,
#  'клоб': <gensim.models.keyedvectors.Vocab at 0x1577c80fda0>,
#  'эскимоский': <gensim.models.keyedvectors.Vocab at 0x1571cbd89b0>,
#  'симилак': <gensim.models.keyedvectors.Vocab at 0x1577e21fcf8>,
#  'аламбо': <gensim.models.keyedvectors.Vocab at 0x1571c75c208>,
#  'poloniae': <gensim.models.keyedvectors.Vocab at 0x1571c5ec5c0>,
#  'пропотевание': <gensim.models.keyedvectors.Vocab at 0x1571ec64d68>,
#  'напрасный': <gensim.models.keyedvectors.Vocab at 0x15777ec0a90>,
#  'стукание': <gensim.models.keyedvectors.Vocab at 0x1577c453240>,
#  'нищать': <gensim.models.keyedvectors.Vocab at 0x1577a0aedd8>,
#  'гроссберг': <gensim.models.keyedvectors.Vocab at 0x1571bd49208>,
#  'чумбур': <gensim.models.keyedvectors.Vocab at 0x15779ce7da0>,
#  'астроляр': <gensim.models.keyedvectors.Vocab at 0x15721b45c88>,
#  'акакиевич': <gensim.models.keyedvectors.Vocab at 0x157798c2940>,
#  'мерль': <gensim.models.keyedvectors.Vocab at 0x1577ae05ac8>,
#  'дилором': <gensim.models.keyedvectors.Vocab at 0x1577a8e8a58>,
#  'избиратель': <gensim.models.keyedvectors.Vocab at 0x15777d8bac8>,
#  'дромомания': <gensim.models.keyedvectors.Vocab at 0x1577d155c88>,
#  'fox': <gensim.models.keyedvectors.Vocab at 0x1577a37c080>,
#  'калиевич': <gensim.models.keyedvectors.Vocab at 0x1571bfabdd8>,
#  'минэкономразвития': <gensim.models.keyedvectors.Vocab at 0x15777fc86a0>,
#  'неэлектролит': <gensim.models.keyedvectors.Vocab at 0x1571c31be10>,
#  'memoria': <gensim.models.keyedvectors.Vocab at 0x1571c1d1518>,
#  'сипирать': <gensim.models.keyedvectors.Vocab at 0x1577c14d940>,
#  'степлаг': <gensim.models.keyedvectors.Vocab at 0x1571e515278>,
#  'poltrona': <gensim.models.keyedvectors.Vocab at 0x1571c5dda20>,
#  'ордонанс': <gensim.models.keyedvectors.Vocab at 0x1577c49f6a0>,
#  'марганцовистый': <gensim.models.keyedvectors.Vocab at 0x1577d0fee80>,
#  'перепихон': <gensim.models.keyedvectors.Vocab at 0x1577f65e4e0>,
#  'прок': <gensim.models.keyedvectors.Vocab at 0x1577844acc0>,
#  'тарбут': <gensim.models.keyedvectors.Vocab at 0x1577aab2518>,
#  'чтов': <gensim.models.keyedvectors.Vocab at 0x1571e428ef0>,
#  'карловка': <gensim.models.keyedvectors.Vocab at 0x1577a94d588>,
#  'бастующий': <gensim.models.keyedvectors.Vocab at 0x1577828d5f8>,
#  'узница': <gensim.models.keyedvectors.Vocab at 0x1577a1a6780>,
#  'буцефал': <gensim.models.keyedvectors.Vocab at 0x1577c240710>,
#  'колумно': <gensim.models.keyedvectors.Vocab at 0x1577d0cda90>,
#  'дрок': <gensim.models.keyedvectors.Vocab at 0x15778585e48>,
#  'мондино': <gensim.models.keyedvectors.Vocab at 0x1571c9259e8>,
#  'ралиф': <gensim.models.keyedvectors.Vocab at 0x1577c576898>,
#  'илларионовский': <gensim.models.keyedvectors.Vocab at 0x1571c033358>,
#  'давасигчить': <gensim.models.keyedvectors.Vocab at 0x1577ffae7b8>,
#  'колымполк': <gensim.models.keyedvectors.Vocab at 0x1571cca4e80>,
#  'цельновирионный': <gensim.models.keyedvectors.Vocab at 0x1577c1f8710>,
#  'транспортировать': <gensim.models.keyedvectors.Vocab at 0x1577850b6d8>,
#  'предостаточно': <gensim.models.keyedvectors.Vocab at 0x15778211dd8>,
#  'кугут': <gensim.models.keyedvectors.Vocab at 0x1577a971ba8>,
#  'паркинсон': <gensim.models.keyedvectors.Vocab at 0x157798fa780>,
#  'поднапираться': <gensim.models.keyedvectors.Vocab at 0x1571e4f39e8>,
#  'слоним': <gensim.models.keyedvectors.Vocab at 0x15779d8eef0>,
#  'хотьково': <gensim.models.keyedvectors.Vocab at 0x1577a175908>,
#  'мэрфельд': <gensim.models.keyedvectors.Vocab at 0x157219ec2e8>,
#  'пуцик': <gensim.models.keyedvectors.Vocab at 0x1571bdeff28>,
#  'койот': <gensim.models.keyedvectors.Vocab at 0x15779f613c8>,
#  'касан': <gensim.models.keyedvectors.Vocab at 0x1577fb0a4a8>,
#  'несмешной': <gensim.models.keyedvectors.Vocab at 0x15779f48748>,
#  'стэлла': <gensim.models.keyedvectors.Vocab at 0x1577c39add8>,
#  'милет': <gensim.models.keyedvectors.Vocab at 0x1577c704048>,
#  'костюмирование': <gensim.models.keyedvectors.Vocab at 0x1571c337f98>,
#  'kounitsyn': <gensim.models.keyedvectors.Vocab at 0x1571cae0780>,
#  'культурология': <gensim.models.keyedvectors.Vocab at 0x15779fc3048>,
#  'крымревком': <gensim.models.keyedvectors.Vocab at 0x1571c8603c8>,
#  'некромантия': <gensim.models.keyedvectors.Vocab at 0x15779b850b8>,
#  'воспитывать': <gensim.models.keyedvectors.Vocab at 0x15777ce42e8>,
#  'гринвуд': <gensim.models.keyedvectors.Vocab at 0x1577c85c668>,
#  'давнехонько': <gensim.models.keyedvectors.Vocab at 0x15721b48e10>,
#  'докомплектовать': <gensim.models.keyedvectors.Vocab at 0x1571e115550>,
#  'ленина': <gensim.models.keyedvectors.Vocab at 0x1577c6400b8>,
#  'манукян': <gensim.models.keyedvectors.Vocab at 0x15779e07160>,
#  'таюшка': <gensim.models.keyedvectors.Vocab at 0x1577c464940>,
#  'милиционерский': <gensim.models.keyedvectors.Vocab at 0x1577cf80898>,
#  'самаркан': <gensim.models.keyedvectors.Vocab at 0x1577f99cd68>,
#  'гельперин': <gensim.models.keyedvectors.Vocab at 0x1577d19e908>,
#  'дундич': <gensim.models.keyedvectors.Vocab at 0x1577a15c1d0>,
#  'джинальский': <gensim.models.keyedvectors.Vocab at 0x1571c7436d8>,
#  'уста': <gensim.models.keyedvectors.Vocab at 0x15777d31c88>,
#  'отрозненность': <gensim.models.keyedvectors.Vocab at 0x1571c410278>,
#  'отчего': <gensim.models.keyedvectors.Vocab at 0x15777cb9748>,
#  'санктпетербургский': <gensim.models.keyedvectors.Vocab at 0x1577c4da630>,
#  'звынять': <gensim.models.keyedvectors.Vocab at 0x1571c1379e8>,
#  'pudet': <gensim.models.keyedvectors.Vocab at 0x1577bf95f60>,
#  'саркозить': <gensim.models.keyedvectors.Vocab at 0x15779c02710>,
#  'захарья': <gensim.models.keyedvectors.Vocab at 0x1577abb7a90>,
#  'дееспособный': <gensim.models.keyedvectors.Vocab at 0x157786828d0>,
#  'омик': <gensim.models.keyedvectors.Vocab at 0x1571c685f60>,
#  'скородить': <gensim.models.keyedvectors.Vocab at 0x1577ccd1e48>,
#  'остолбенение': <gensim.models.keyedvectors.Vocab at 0x1577a270630>,
#  'либреттист': <gensim.models.keyedvectors.Vocab at 0x1577a2f7a58>,
#  'самолетский': <gensim.models.keyedvectors.Vocab at 0x1577e412d30>,
#  'швартовый': <gensim.models.keyedvectors.Vocab at 0x1577a0e6dd8>,
#  'racing': <gensim.models.keyedvectors.Vocab at 0x15778396470>,
#  'бандгруппа': <gensim.models.keyedvectors.Vocab at 0x1577a2649e8>,
#  'iapa': <gensim.models.keyedvectors.Vocab at 0x1571e1a4940>,
#  'недзведский': <gensim.models.keyedvectors.Vocab at 0x1571e4b5080>,
#  'раздрабливать': <gensim.models.keyedvectors.Vocab at 0x157205b5d30>,
#  'ламивудин': <gensim.models.keyedvectors.Vocab at 0x1577fadbf98>,
#  'пархатый': <gensim.models.keyedvectors.Vocab at 0x1577a07c5f8>,
#  'путинизм': <gensim.models.keyedvectors.Vocab at 0x1577f63de48>,
#  'хевра': <gensim.models.keyedvectors.Vocab at 0x1577c7297b8>,
#  'лилея': <gensim.models.keyedvectors.Vocab at 0x1577a6a6320>,
#  'рпо': <gensim.models.keyedvectors.Vocab at 0x1577c19b080>,
#  'нелингвист': <gensim.models.keyedvectors.Vocab at 0x1577e1fd160>,
#  'навырезать': <gensim.models.keyedvectors.Vocab at 0x1571e097dd8>,
#  'шмультке': <gensim.models.keyedvectors.Vocab at 0x1577a6bacf8>,
#  'протактиниевый': <gensim.models.keyedvectors.Vocab at 0x1571cb25ef0>,
#  'борхеса': <gensim.models.keyedvectors.Vocab at 0x1577a016128>,
#  'прогалина': <gensim.models.keyedvectors.Vocab at 0x157785eac18>,
#  'визитка': <gensim.models.keyedvectors.Vocab at 0x157781c1208>,
#  'пирей': <gensim.models.keyedvectors.Vocab at 0x15779d78128>,
#  'руманов': <gensim.models.keyedvectors.Vocab at 0x1577e1bb828>,
#  'кондиционировать': <gensim.models.keyedvectors.Vocab at 0x1577a08ceb8>,
#  'оттопатывать': <gensim.models.keyedvectors.Vocab at 0x1577f9f3a58>,
#  'подколокольный': <gensim.models.keyedvectors.Vocab at 0x1577c27b898>,
#  'мелодийный': <gensim.models.keyedvectors.Vocab at 0x1571e4f3278>,
#  'магелланов': <gensim.models.keyedvectors.Vocab at 0x1577a306ba8>,
#  'сигида': <gensim.models.keyedvectors.Vocab at 0x1577caba2b0>,
#  'висельный': <gensim.models.keyedvectors.Vocab at 0x1577bfe6d68>,
#  'радиевич': <gensim.models.keyedvectors.Vocab at 0x1577f5a5eb8>,
#  'нашенький': <gensim.models.keyedvectors.Vocab at 0x1577cc49ba8>,
#  'четырехэтажка': <gensim.models.keyedvectors.Vocab at 0x1577cd83320>,
#  'старошаса': <gensim.models.keyedvectors.Vocab at 0x1577c32c128>,
#  'bosh': <gensim.models.keyedvectors.Vocab at 0x1577fca3438>,
#  'зеленовец': <gensim.models.keyedvectors.Vocab at 0x1577fad5fd0>,
#  'канталь': <gensim.models.keyedvectors.Vocab at 0x1577ff5e400>,
#  'пляц': <gensim.models.keyedvectors.Vocab at 0x1577fbaf208>,
#  'алехарка': <gensim.models.keyedvectors.Vocab at 0x157207ec080>,
#  'готоп': <gensim.models.keyedvectors.Vocab at 0x1577a614cf8>,
#  'академснаб': <gensim.models.keyedvectors.Vocab at 0x1577abda1d0>,
#  'анненский': <gensim.models.keyedvectors.Vocab at 0x1577818e2e8>,
#  'итерационный': <gensim.models.keyedvectors.Vocab at 0x1577a6929e8>,
#  'малопривычный': <gensim.models.keyedvectors.Vocab at 0x1571c4e6828>,
#  'клещовый': <gensim.models.keyedvectors.Vocab at 0x1577be62cf8>,
#  'увечная': <gensim.models.keyedvectors.Vocab at 0x1577cfb8cf8>,
#  'метина': <gensim.models.keyedvectors.Vocab at 0x15779c62d30>,
#  'гамидие': <gensim.models.keyedvectors.Vocab at 0x1577c7c15c0>,
#  'дство': <gensim.models.keyedvectors.Vocab at 0x1577e49a240>,
#  'котцов': <gensim.models.keyedvectors.Vocab at 0x1577aceab00>,
#  'хонтуев': <gensim.models.keyedvectors.Vocab at 0x15721b01828>,
#  'выдергивать': <gensim.models.keyedvectors.Vocab at 0x15777e6bd30>,
#  'абдулло': <gensim.models.keyedvectors.Vocab at 0x1577c7c7a58>,
#  'швиллер': <gensim.models.keyedvectors.Vocab at 0x1571c880240>,
#  'глобулин': <gensim.models.keyedvectors.Vocab at 0x15779f52080>,
#  'самогудка': <gensim.models.keyedvectors.Vocab at 0x15779bbbac8>,
#  'люзьена': <gensim.models.keyedvectors.Vocab at 0x1571c316ef0>,
#  'спиздеть': <gensim.models.keyedvectors.Vocab at 0x15721aa9208>,
#  'oe': <gensim.models.keyedvectors.Vocab at 0x1577ca60390>,
#  'деструктор': <gensim.models.keyedvectors.Vocab at 0x1577f857a20>,
#  'калеви': <gensim.models.keyedvectors.Vocab at 0x1571c2d74a8>,
#  'альми': <gensim.models.keyedvectors.Vocab at 0x1577c471240>,
#  'morituri': <gensim.models.keyedvectors.Vocab at 0x1577c8617b8>,
#  'оштукатуривать': <gensim.models.keyedvectors.Vocab at 0x157799599b0>,
#  'засеменять': <gensim.models.keyedvectors.Vocab at 0x1577f57fc18>,
#  'физис': <gensim.models.keyedvectors.Vocab at 0x1577c240320>,
#  'обоготворяться': <gensim.models.keyedvectors.Vocab at 0x1577aac7ef0>,
#  'луаян': <gensim.models.keyedvectors.Vocab at 0x1577c30ac50>,
#  'желтошапочник': <gensim.models.keyedvectors.Vocab at 0x1571c6bf940>,
#  'нерасписывать': <gensim.models.keyedvectors.Vocab at 0x1577c95dbe0>,
#  'оскский': <gensim.models.keyedvectors.Vocab at 0x1577fbaf6a0>,
#  'лжемемуар': <gensim.models.keyedvectors.Vocab at 0x1571deb2a90>,
#  'шишацкая': <gensim.models.keyedvectors.Vocab at 0x1571e0d6668>,
#  'пособираться': <gensim.models.keyedvectors.Vocab at 0x1577ad30358>,
#  'мурка': <gensim.models.keyedvectors.Vocab at 0x1577856f080>,
#  'краупишкен': <gensim.models.keyedvectors.Vocab at 0x1577f7cd240>,
#  'неисчезающий': <gensim.models.keyedvectors.Vocab at 0x1577c07b1d0>,
#  'ассесор': <gensim.models.keyedvectors.Vocab at 0x1577e48c630>,
#  'пылесборный': <gensim.models.keyedvectors.Vocab at 0x15721a5fe48>,
#  'развеивание': <gensim.models.keyedvectors.Vocab at 0x1577e371748>,
#  'крамовский': <gensim.models.keyedvectors.Vocab at 0x1577c3f39b0>,
#  'внесофийный': <gensim.models.keyedvectors.Vocab at 0x1571c21b630>,
#  'зернотерка': <gensim.models.keyedvectors.Vocab at 0x1577ad981d0>,
#  'мудрица': <gensim.models.keyedvectors.Vocab at 0x1571bc8c9e8>,
#  'срамить': <gensim.models.keyedvectors.Vocab at 0x1577996ce48>,
#  'serial': <gensim.models.keyedvectors.Vocab at 0x1577e1a5320>,
#  'formaliter': <gensim.models.keyedvectors.Vocab at 0x1572074f860>,
#  'записной': <gensim.models.keyedvectors.Vocab at 0x15777e2d668>,
#  'обломочный': <gensim.models.keyedvectors.Vocab at 0x15779cb1128>,
#  'тайгетский': <gensim.models.keyedvectors.Vocab at 0x157207d5c50>,
#  'крестовникова': <gensim.models.keyedvectors.Vocab at 0x1577f58b3c8>,
#  'luella': <gensim.models.keyedvectors.Vocab at 0x1571df0e0b8>,
#  'гипсолюбка': <gensim.models.keyedvectors.Vocab at 0x1577ace0390>,
#  'europaeus': <gensim.models.keyedvectors.Vocab at 0x1577c978470>,
#  'ландскрона': <gensim.models.keyedvectors.Vocab at 0x1577c6ab7b8>,
#  'резон': <gensim.models.keyedvectors.Vocab at 0x15778094278>,
#  'магнезиоферритовый': <gensim.models.keyedvectors.Vocab at 0x1577fa93518>,
#  'трюкачество': <gensim.models.keyedvectors.Vocab at 0x1577a71a1d0>,
#  'хивать': <gensim.models.keyedvectors.Vocab at 0x1571e6f3358>,
#  'чувствоваться': <gensim.models.keyedvectors.Vocab at 0x15777d0da58>,
#  'новоселок': <gensim.models.keyedvectors.Vocab at 0x1572060ddd8>,
#  'вверху': <gensim.models.keyedvectors.Vocab at 0x15777e7bc88>,
#  'осокорь': <gensim.models.keyedvectors.Vocab at 0x157799e94a8>,
#  'хен': <gensim.models.keyedvectors.Vocab at 0x1577c2f7400>,
#  'хаффман': <gensim.models.keyedvectors.Vocab at 0x1577f3c84a8>,
#  'заклинивание': <gensim.models.keyedvectors.Vocab at 0x1577a501550>,
#  'мантагуров': <gensim.models.keyedvectors.Vocab at 0x1571dd18e80>,
#  'возражатель': <gensim.models.keyedvectors.Vocab at 0x1577c974278>,
#  'privacy': <gensim.models.keyedvectors.Vocab at 0x1577a80f518>,
#  'ножный': <gensim.models.keyedvectors.Vocab at 0x1577aa07908>,
#  'туберкулез': <gensim.models.keyedvectors.Vocab at 0x15777f2aac8>,
#  'robotics': <gensim.models.keyedvectors.Vocab at 0x1571be92748>,
#  'хлясть': <gensim.models.keyedvectors.Vocab at 0x1577f3b9668>,
#  'исааковна': <gensim.models.keyedvectors.Vocab at 0x15779f7c780>,
#  'энергопакет': <gensim.models.keyedvectors.Vocab at 0x1577a306588>,
#  'дерожинский': <gensim.models.keyedvectors.Vocab at 0x157219a7b00>,
#  'обобщитель': <gensim.models.keyedvectors.Vocab at 0x15720622550>,
#  'обергаузен': <gensim.models.keyedvectors.Vocab at 0x1571ca8db38>,
#  'dodge': <gensim.models.keyedvectors.Vocab at 0x1577c9ffb70>,
#  'перемолачивать': <gensim.models.keyedvectors.Vocab at 0x1577c273208>,
#  'живознание': <gensim.models.keyedvectors.Vocab at 0x1577e244208>,
#  'двуслойность': <gensim.models.keyedvectors.Vocab at 0x1571bfe70f0>,
#  'верноподданно': <gensim.models.keyedvectors.Vocab at 0x1577c922d30>,
#  'нежелательность': <gensim.models.keyedvectors.Vocab at 0x1577a1f3080>,
#  'clip': <gensim.models.keyedvectors.Vocab at 0x1577cd9de80>,
#  'колумье': <gensim.models.keyedvectors.Vocab at 0x1571bcf2470>,
#  'вивисекционный': <gensim.models.keyedvectors.Vocab at 0x1577f99f2b0>,
#  'дво': <gensim.models.keyedvectors.Vocab at 0x1577a68def0>,
#  'катыс': <gensim.models.keyedvectors.Vocab at 0x1577be7c978>,
#  'внестеп': <gensim.models.keyedvectors.Vocab at 0x1577e263cc0>,
#  'empire': <gensim.models.keyedvectors.Vocab at 0x1577a5ecdd8>,
#  'вонми': <gensim.models.keyedvectors.Vocab at 0x1577c6fba20>,
#  'нетрудоемкий': <gensim.models.keyedvectors.Vocab at 0x1577f2a1e10>,
#  'икемчик': <gensim.models.keyedvectors.Vocab at 0x1577cee8048>,
#  'косторезный': <gensim.models.keyedvectors.Vocab at 0x15779ca0748>,
#  'доядерный': <gensim.models.keyedvectors.Vocab at 0x15721994d30>,
#  'электросетевой': <gensim.models.keyedvectors.Vocab at 0x1577a5152b0>,
#  'размежевывать': <gensim.models.keyedvectors.Vocab at 0x1577a6b4ac8>,
#  'оцеплять': <gensim.models.keyedvectors.Vocab at 0x157781a4f28>,
#  'шпионка': <gensim.models.keyedvectors.Vocab at 0x157797b4588>,
#  'купейный': <gensim.models.keyedvectors.Vocab at 0x15779e37668>,
#  'мордки': <gensim.models.keyedvectors.Vocab at 0x1571c875ac8>,
#  'марголина': <gensim.models.keyedvectors.Vocab at 0x15779b689e8>,
#  'куклусклановец': <gensim.models.keyedvectors.Vocab at 0x15721a1f2b0>,
#  'гермес': <gensim.models.keyedvectors.Vocab at 0x15778594cf8>,
#  'седмиозерский': <gensim.models.keyedvectors.Vocab at 0x1571ec55f60>,
#  'радостно': <gensim.models.keyedvectors.Vocab at 0x15777cc4630>,
#  'лурман': <gensim.models.keyedvectors.Vocab at 0x1577caa25f8>,
#  'nouveau': <gensim.models.keyedvectors.Vocab at 0x15779aa5ef0>,
#  'колдоговорный': <gensim.models.keyedvectors.Vocab at 0x1577c34e9e8>,
#  'баут': <gensim.models.keyedvectors.Vocab at 0x1577add9c88>,
#  'китат': <gensim.models.keyedvectors.Vocab at 0x1577e20afd0>,
#  'вейдлинг': <gensim.models.keyedvectors.Vocab at 0x1577a30b668>,
#  'скипора': <gensim.models.keyedvectors.Vocab at 0x1577d07c1d0>,
#  'импириал': <gensim.models.keyedvectors.Vocab at 0x1571cc23358>,
#  'полианион': <gensim.models.keyedvectors.Vocab at 0x1577aa89128>,
#  'смрити': <gensim.models.keyedvectors.Vocab at 0x1571e67f4a8>,
#  'невосприимчивый': <gensim.models.keyedvectors.Vocab at 0x1577a0ae3c8>,
#  'ройзензон': <gensim.models.keyedvectors.Vocab at 0x15720570358>,
#  'колобаев': <gensim.models.keyedvectors.Vocab at 0x1577c7e56a0>,
#  'фейнулиться': <gensim.models.keyedvectors.Vocab at 0x157205cfe48>,
#  'замараевский': <gensim.models.keyedvectors.Vocab at 0x1577cb44080>,
#  'половодья': <gensim.models.keyedvectors.Vocab at 0x1571e458240>,
#  'doroga': <gensim.models.keyedvectors.Vocab at 0x15720836d30>,
#  'зарубка': <gensim.models.keyedvectors.Vocab at 0x157785de8d0>,
#  'ревностия': <gensim.models.keyedvectors.Vocab at 0x1577fac58d0>,
#  'велоавтомобиль': <gensim.models.keyedvectors.Vocab at 0x1571cb4a2b0>,
#  'усмотренческий': <gensim.models.keyedvectors.Vocab at 0x1571dfa35f8>,
#  'frugilegus': <gensim.models.keyedvectors.Vocab at 0x1571e522160>,
#  'круча': <gensim.models.keyedvectors.Vocab at 0x15778259208>,
#  'премудрый': <gensim.models.keyedvectors.Vocab at 0x157784d72e8>,
#  'малолитражка': <gensim.models.keyedvectors.Vocab at 0x1577a0be7b8>,
#  'склад': <gensim.models.keyedvectors.Vocab at 0x15777cb9b38>,
#  'динамометрический': <gensim.models.keyedvectors.Vocab at 0x1577e3ffeb8>,
#  'одревеснеть': <gensim.models.keyedvectors.Vocab at 0x1577c04f1d0>,
#  'войска': <gensim.models.keyedvectors.Vocab at 0x1577c22b710>,
#  'истребляться': <gensim.models.keyedvectors.Vocab at 0x15779ea4ef0>,
#  'тритгемия': <gensim.models.keyedvectors.Vocab at 0x1577fa05a20>,
#  'буджолд': <gensim.models.keyedvectors.Vocab at 0x1577e219320>,
#  'стерильность': <gensim.models.keyedvectors.Vocab at 0x157782fd908>,
#  'петротеть': <gensim.models.keyedvectors.Vocab at 0x1571c3e3cc0>,
#  'помпонаццо': <gensim.models.keyedvectors.Vocab at 0x1571e1d0f98>,
#  'птеранодон': <gensim.models.keyedvectors.Vocab at 0x1577e3c2278>,
#  'ферфлюхтер': <gensim.models.keyedvectors.Vocab at 0x1577c9029b0>,
#  'безресницый': <gensim.models.keyedvectors.Vocab at 0x1571e2372e8>,
#  'карбатальон': <gensim.models.keyedvectors.Vocab at 0x1571c016c50>,
#  'видеоконференц': <gensim.models.keyedvectors.Vocab at 0x1571c69e550>,
#  'считать': <gensim.models.keyedvectors.Vocab at 0x1577766a908>,
#  'усиливаться': <gensim.models.keyedvectors.Vocab at 0x15777d4d8d0>,
#  'вотч': <gensim.models.keyedvectors.Vocab at 0x1577fa0a240>,
#  'наbitat': <gensim.models.keyedvectors.Vocab at 0x1577fbd3b00>,
#  'самари': <gensim.models.keyedvectors.Vocab at 0x15720717cf8>,
#  'подрядный': <gensim.models.keyedvectors.Vocab at 0x15779702c88>,
#  'micrococcus': <gensim.models.keyedvectors.Vocab at 0x1577cebc208>,
#  'прахарь': <gensim.models.keyedvectors.Vocab at 0x1577abe9eb8>,
#  'делительный': <gensim.models.keyedvectors.Vocab at 0x1577c78c7f0>,
#  'гря': <gensim.models.keyedvectors.Vocab at 0x1577bec3080>,
#  'gibco': <gensim.models.keyedvectors.Vocab at 0x1577a755080>,
#  'позлорадствовать': <gensim.models.keyedvectors.Vocab at 0x1577a7a1e80>,
#  'тексиер': <gensim.models.keyedvectors.Vocab at 0x15721af0358>,
#  'прогрессизм': <gensim.models.keyedvectors.Vocab at 0x1577c4e3d68>,
#  'раззадоривать': <gensim.models.keyedvectors.Vocab at 0x15779930dd8>,
#  'доступно': <gensim.models.keyedvectors.Vocab at 0x157781d2d68>,
#  'снизка': <gensim.models.keyedvectors.Vocab at 0x1577c2bd668>,
#  'божениновский': <gensim.models.keyedvectors.Vocab at 0x1577f868630>,
#  'подосланец': <gensim.models.keyedvectors.Vocab at 0x1577f4eb320>,
#  'уябывать': <gensim.models.keyedvectors.Vocab at 0x1571c643550>,
#  'динама': <gensim.models.keyedvectors.Vocab at 0x1577c2b2c88>,
#  'гуэп': <gensim.models.keyedvectors.Vocab at 0x15721b8d438>,
#  'ргн': <gensim.models.keyedvectors.Vocab at 0x1577ad26390>,
#  'проверьянц': <gensim.models.keyedvectors.Vocab at 0x1571e687390>,
#  'незавершимость': <gensim.models.keyedvectors.Vocab at 0x1577c851438>,
#  'лексикограф': <gensim.models.keyedvectors.Vocab at 0x15779a72208>,
#  'околоплодник': <gensim.models.keyedvectors.Vocab at 0x1577aa0c668>,
#  'ррт': <gensim.models.keyedvectors.Vocab at 0x1577a67a198>,
#  'конецгорский': <gensim.models.keyedvectors.Vocab at 0x1571e285978>,
#  'крцаниси': <gensim.models.keyedvectors.Vocab at 0x1577f7e4160>,
#  'накусывать': <gensim.models.keyedvectors.Vocab at 0x1577e19c8d0>,
#  'ненагретый': <gensim.models.keyedvectors.Vocab at 0x1571c2c7438>,
#  'альфа-банк': <gensim.models.keyedvectors.Vocab at 0x15779712978>,
#  'рибавирин': <gensim.models.keyedvectors.Vocab at 0x1577a7756a0>,
#  'рокабилли': <gensim.models.keyedvectors.Vocab at 0x1577fa79c88>,
#  'контрнаступательный': <gensim.models.keyedvectors.Vocab at 0x1571c1fa2e8>,
#  'ямомото': <gensim.models.keyedvectors.Vocab at 0x15779f14780>,
#  'четырехгодовой': <gensim.models.keyedvectors.Vocab at 0x1571e3122b0>,
#  'батчаев': <gensim.models.keyedvectors.Vocab at 0x1577caeaa58>,
#  'невосторженный': <gensim.models.keyedvectors.Vocab at 0x1571e3f1b70>,
#  'грузоподъемность': <gensim.models.keyedvectors.Vocab at 0x15778125dd8>,
#  'ремонтно-восстановительный': <gensim.models.keyedvectors.Vocab at 0x1577a202860>,
#  'мирабелла': <gensim.models.keyedvectors.Vocab at 0x1571ebeaf98>,
#  'культурфилософ': <gensim.models.keyedvectors.Vocab at 0x1571c2c2da0>,
#  'барограф': <gensim.models.keyedvectors.Vocab at 0x1577a8147f0>,
#  'худяковский': <gensim.models.keyedvectors.Vocab at 0x1571c93d5f8>,
#  'бюклинг': <gensim.models.keyedvectors.Vocab at 0x1577cfd4c88>,
#  'кримсон': <gensim.models.keyedvectors.Vocab at 0x1577d0f9860>,
#  'vг': <gensim.models.keyedvectors.Vocab at 0x1571bfd75f8>,
#  'неединый': <gensim.models.keyedvectors.Vocab at 0x15720708278>,
#  'электросталеплавильный': <gensim.models.keyedvectors.Vocab at 0x1577a775128>,
#  'жестянница': <gensim.models.keyedvectors.Vocab at 0x1577c1af630>,
#  'ретроактивный': <gensim.models.keyedvectors.Vocab at 0x1577fb7fcc0>,
#  'блатняк': <gensim.models.keyedvectors.Vocab at 0x15779abfb38>,
#  'климентьевский': <gensim.models.keyedvectors.Vocab at 0x1571c1f52b0>,
#  'стопорить': <gensim.models.keyedvectors.Vocab at 0x1577a4a2470>,
#  'грибера': <gensim.models.keyedvectors.Vocab at 0x1571c04b400>,
#  'сидьмь': <gensim.models.keyedvectors.Vocab at 0x1577e5677f0>,
#  'счетовод': <gensim.models.keyedvectors.Vocab at 0x15778472710>,
#  'мелконарубать': <gensim.models.keyedvectors.Vocab at 0x1571c920ef0>,
#  'рашум': <gensim.models.keyedvectors.Vocab at 0x1577e4b1eb8>,
#  'фталоцианиновый': <gensim.models.keyedvectors.Vocab at 0x1577cb09828>,
#  'напульсник': <gensim.models.keyedvectors.Vocab at 0x1577e487828>,
#  'жм': <gensim.models.keyedvectors.Vocab at 0x1577f5bee80>,
#  'учреда': <gensim.models.keyedvectors.Vocab at 0x1577ca057f0>,
#  'неэнергичный': <gensim.models.keyedvectors.Vocab at 0x157206837f0>,
#  'рыбища': <gensim.models.keyedvectors.Vocab at 0x1577e42e320>,
#  'нем': <gensim.models.keyedvectors.Vocab at 0x1577c92bd30>,
#  'брантовый': <gensim.models.keyedvectors.Vocab at 0x1577cba0ac8>,
#  'музшкола': <gensim.models.keyedvectors.Vocab at 0x1571e649ac8>,
#  'асбестотехнический': <gensim.models.keyedvectors.Vocab at 0x1571e80c0b8>,
#  'ревнивость': <gensim.models.keyedvectors.Vocab at 0x1577ca050f0>,
#  'шафагат': <gensim.models.keyedvectors.Vocab at 0x1577f1c1470>,
#  'изумление': <gensim.models.keyedvectors.Vocab at 0x15777d7ce10>,
#  'хилга': <gensim.models.keyedvectors.Vocab at 0x157207b82b0>,
#  'явилася': <gensim.models.keyedvectors.Vocab at 0x1577c624080>,
#  'склубиться': <gensim.models.keyedvectors.Vocab at 0x1577cbcc160>,
#  'невнесение': <gensim.models.keyedvectors.Vocab at 0x1577bff1a58>,
#  'гельба': <gensim.models.keyedvectors.Vocab at 0x1577c660eb8>,
#  'фоломевич': <gensim.models.keyedvectors.Vocab at 0x1577f95d7b8>,
#  'муштавер': <gensim.models.keyedvectors.Vocab at 0x1577ada90b8>,
#  'плева': <gensim.models.keyedvectors.Vocab at 0x1577803ce10>,
#  'райрыболовпотребсоюз': <gensim.models.keyedvectors.Vocab at 0x1571e1f3ba8>,
#  'прерафаэлит': <gensim.models.keyedvectors.Vocab at 0x1577a814908>,
#  'доде': <gensim.models.keyedvectors.Vocab at 0x1577a31f2e8>,
#  'пьерфитт': <gensim.models.keyedvectors.Vocab at 0x1571e1b4c18>,
#  'терм': <gensim.models.keyedvectors.Vocab at 0x1577a1ee6d8>,
#  'herzen': <gensim.models.keyedvectors.Vocab at 0x1571e0df2e8>,
#  'городской': <gensim.models.keyedvectors.Vocab at 0x15777c50ba8>,
#  'арденне': <gensim.models.keyedvectors.Vocab at 0x1577f2859e8>,
#  'кануня': <gensim.models.keyedvectors.Vocab at 0x15720822278>,
#  'соматический': <gensim.models.keyedvectors.Vocab at 0x157781d24e0>,
#  'гпг': <gensim.models.keyedvectors.Vocab at 0x1577c5e9320>,
#  'кощун': <gensim.models.keyedvectors.Vocab at 0x1571bd5c320>,
#  'сихотэ-алиньский': <gensim.models.keyedvectors.Vocab at 0x1577bf02240>,
#  'фетишист': <gensim.models.keyedvectors.Vocab at 0x15779ca6400>,
#  'уитби': <gensim.models.keyedvectors.Vocab at 0x1577f6a54e0>,
#  'погулянка': <gensim.models.keyedvectors.Vocab at 0x1577c3cb898>,
#  'мурашко': <gensim.models.keyedvectors.Vocab at 0x1577a79cc18>,
#  'верховье': <gensim.models.keyedvectors.Vocab at 0x15777fe2198>,
#  'тби': <gensim.models.keyedvectors.Vocab at 0x1577f6b6a20>,
#  'абрь': <gensim.models.keyedvectors.Vocab at 0x1577a50c6d8>,
#  'комучать': <gensim.models.keyedvectors.Vocab at 0x1577d0d2ef0>,
#  'хомут': <gensim.models.keyedvectors.Vocab at 0x157780d4518>,
#  'агай': <gensim.models.keyedvectors.Vocab at 0x1577c258b00>,
#  'хлопотов': <gensim.models.keyedvectors.Vocab at 0x1571de9f978>,
#  'беллетризированный': <gensim.models.keyedvectors.Vocab at 0x1577cbfda90>,
#  'спортбар': <gensim.models.keyedvectors.Vocab at 0x1577f7af898>,
#  'кара-куль': <gensim.models.keyedvectors.Vocab at 0x1577a814128>,
#  'кемпка': <gensim.models.keyedvectors.Vocab at 0x1577cdc7cf8>,
#  'гернуть': <gensim.models.keyedvectors.Vocab at 0x1577cd746d8>,
#  'маиг': <gensim.models.keyedvectors.Vocab at 0x15779b62a20>,
#  'желтоватый': <gensim.models.keyedvectors.Vocab at 0x15777edbf98>,
#  'мадебейкин': <gensim.models.keyedvectors.Vocab at 0x1577ffcb5c0>,
#  'туманник': <gensim.models.keyedvectors.Vocab at 0x1571e75e588>,
#  'франстеха': <gensim.models.keyedvectors.Vocab at 0x1571e156048>,
#  'theta': <gensim.models.keyedvectors.Vocab at 0x1577c2bd128>,
#  'сорганизовываться': <gensim.models.keyedvectors.Vocab at 0x157783e8198>,
#  'давеча': <gensim.models.keyedvectors.Vocab at 0x15777ff1898>,
#  'фундуклеевка': <gensim.models.keyedvectors.Vocab at 0x1577e1779b0>,
#  'волчин': <gensim.models.keyedvectors.Vocab at 0x1577e394898>,
#  'дозорить': <gensim.models.keyedvectors.Vocab at 0x15779c499e8>,
#  'ривкин': <gensim.models.keyedvectors.Vocab at 0x1577beabba8>,
#  'идеалистический': <gensim.models.keyedvectors.Vocab at 0x15778037fd0>,
#  'рейхсталлер': <gensim.models.keyedvectors.Vocab at 0x1571c5b6278>,
#  'геомантия': <gensim.models.keyedvectors.Vocab at 0x1572077ed68>,
#  'режица': <gensim.models.keyedvectors.Vocab at 0x15779cf12e8>,
#  'талбот': <gensim.models.keyedvectors.Vocab at 0x1577cc0e630>,
#  'джованна': <gensim.models.keyedvectors.Vocab at 0x1577bf8ba20>,
#  'исламов': <gensim.models.keyedvectors.Vocab at 0x1577c45eda0>,
#  'гексаметр': <gensim.models.keyedvectors.Vocab at 0x1577ace5400>,
#  'природоведение': <gensim.models.keyedvectors.Vocab at 0x15779e3c400>,
#  'малоузнаваемый': <gensim.models.keyedvectors.Vocab at 0x1571e2ebb38>,
#  'куэб': <gensim.models.keyedvectors.Vocab at 0x1571e417c18>,
#  'тенет': <gensim.models.keyedvectors.Vocab at 0x1577c961c18>,
#  'хохотливый': <gensim.models.keyedvectors.Vocab at 0x1577a93c208>,
#  'покоробить': <gensim.models.keyedvectors.Vocab at 0x1577862d278>,
#  'саморазрушение': <gensim.models.keyedvectors.Vocab at 0x15779dc9160>,
#  'кулорес': <gensim.models.keyedvectors.Vocab at 0x1571c44a4a8>,
#  'барочник': <gensim.models.keyedvectors.Vocab at 0x1571e13df98>,
#  'парприз': <gensim.models.keyedvectors.Vocab at 0x1577be68a20>,
#  'пятиглавый': <gensim.models.keyedvectors.Vocab at 0x1577a3e2240>,
#  'артвинский': <gensim.models.keyedvectors.Vocab at 0x1571c7a04e0>,
#  'ревель': <gensim.models.keyedvectors.Vocab at 0x157781b2438>,
#  'штырьковый': <gensim.models.keyedvectors.Vocab at 0x15720720588>,
#  'пятиразрядный': <gensim.models.keyedvectors.Vocab at 0x1577f335198>,
#  'спасание': <gensim.models.keyedvectors.Vocab at 0x1577a38bc88>,
#  'дайос': <gensim.models.keyedvectors.Vocab at 0x157219a3cf8>,
#  'callosum': <gensim.models.keyedvectors.Vocab at 0x1577f60bf60>,
#  'ватолин': <gensim.models.keyedvectors.Vocab at 0x1577f99f470>,
#  'ахор': <gensim.models.keyedvectors.Vocab at 0x1577aac0208>,
#  'вылязать': <gensim.models.keyedvectors.Vocab at 0x1571e799860>,
#  'форка': <gensim.models.keyedvectors.Vocab at 0x1572065cf60>,
#  'достопочтимый': <gensim.models.keyedvectors.Vocab at 0x1571e33e9e8>,
#  'токагэ': <gensim.models.keyedvectors.Vocab at 0x1577d177ef0>,
#  'иремеля': <gensim.models.keyedvectors.Vocab at 0x1571c9c7e10>,
#  'экзальтация': <gensim.models.keyedvectors.Vocab at 0x157797e7518>,
#  'обмоклый': <gensim.models.keyedvectors.Vocab at 0x1571e293ba8>,
#  'псм': <gensim.models.keyedvectors.Vocab at 0x1577a264be0>,
#  'распараллеливать': <gensim.models.keyedvectors.Vocab at 0x1577cd6f2e8>,
#  'интригующий': <gensim.models.keyedvectors.Vocab at 0x15779741198>,
#  'однократность': <gensim.models.keyedvectors.Vocab at 0x1577a8e86d8>,
#  'начитка': <gensim.models.keyedvectors.Vocab at 0x157219b0908>,
#  'поратовать': <gensim.models.keyedvectors.Vocab at 0x1571dd146a0>,
#  'космоебянский': <gensim.models.keyedvectors.Vocab at 0x157205d3320>,
#  'желтявый': <gensim.models.keyedvectors.Vocab at 0x1577fc6c940>,
#  'галлюцинаторность': <gensim.models.keyedvectors.Vocab at 0x1571e40c4a8>,
#  'нормализовываться': <gensim.models.keyedvectors.Vocab at 0x1577ac94b70>,
#  'полуударяемый': <gensim.models.keyedvectors.Vocab at 0x1571c8c8780>,
#  'вприклад': <gensim.models.keyedvectors.Vocab at 0x1577f262b70>,
#  'электрогорск': <gensim.models.keyedvectors.Vocab at 0x1577c5a5550>,
#  'асак': <gensim.models.keyedvectors.Vocab at 0x1571c4efcf8>,
#  'абсолютизировать': <gensim.models.keyedvectors.Vocab at 0x15779f41b00>,
#  'витальевна': <gensim.models.keyedvectors.Vocab at 0x15779f1aba8>,
#  'размножаться': <gensim.models.keyedvectors.Vocab at 0x15777f58668>,
#  'коста': <gensim.models.keyedvectors.Vocab at 0x157780cb550>,
#  'ардовская': <gensim.models.keyedvectors.Vocab at 0x1577f637c88>,
#  'константинова': <gensim.models.keyedvectors.Vocab at 0x1577a7a6d30>,
#  'копытка': <gensim.models.keyedvectors.Vocab at 0x1577c420198>,
#  'еремия': <gensim.models.keyedvectors.Vocab at 0x1571eb90630>,
#  'недополученный': <gensim.models.keyedvectors.Vocab at 0x1577a3ef2b0>,
#  'porca': <gensim.models.keyedvectors.Vocab at 0x15720557240>,
#  'росэстбанка': <gensim.models.keyedvectors.Vocab at 0x157205eb438>,
#  'испаринка': <gensim.models.keyedvectors.Vocab at 0x1577f40d630>,
#  'бескомплексный': <gensim.models.keyedvectors.Vocab at 0x1571e550358>,
#  'алгон': <gensim.models.keyedvectors.Vocab at 0x1577d092208>,
#  'раздолеваться': <gensim.models.keyedvectors.Vocab at 0x1577f6c4cf8>,
#  'умилять': <gensim.models.keyedvectors.Vocab at 0x157784302e8>,
#  'черед': <gensim.models.keyedvectors.Vocab at 0x15777edfb00>,
#  'арматура': <gensim.models.keyedvectors.Vocab at 0x157780d9390>,
#  'адрон': <gensim.models.keyedvectors.Vocab at 0x1577a2ed400>,
#  'кальвинистический': <gensim.models.keyedvectors.Vocab at 0x1571bd49cc0>,
#  'кортико': <gensim.models.keyedvectors.Vocab at 0x1577cd3d668>,
#  'изболтаться': <gensim.models.keyedvectors.Vocab at 0x15720588710>,
#  'турельный': <gensim.models.keyedvectors.Vocab at 0x1577beb81d0>,
#  'аришка': <gensim.models.keyedvectors.Vocab at 0x1577a5f1048>,
#  'попрыгунья': <gensim.models.keyedvectors.Vocab at 0x15779fd3b38>,
#  'колобродченко': <gensim.models.keyedvectors.Vocab at 0x1577f770860>,
#  'древле': <gensim.models.keyedvectors.Vocab at 0x15779c57518>,
#  'перезагружать': <gensim.models.keyedvectors.Vocab at 0x1577c125b38>,
#  'казанок': <gensim.models.keyedvectors.Vocab at 0x157783642b0>,
#  'покорность': <gensim.models.keyedvectors.Vocab at 0x15777f43d68>,
#  'жко': <gensim.models.keyedvectors.Vocab at 0x1571be7eb00>,
#  'гелиосфера': <gensim.models.keyedvectors.Vocab at 0x1571e13da20>,
#  'облесение': <gensim.models.keyedvectors.Vocab at 0x1577a0ccef0>,
#  'вымарывание': <gensim.models.keyedvectors.Vocab at 0x1577fca8438>,
#  'синтезирование': <gensim.models.keyedvectors.Vocab at 0x1577a71f6d8>,
#  'сказнить': <gensim.models.keyedvectors.Vocab at 0x1577bf7ceb8>,
#  'уорент': <gensim.models.keyedvectors.Vocab at 0x1571bf8f9e8>,
#  'альбокрин': <gensim.models.keyedvectors.Vocab at 0x1571c2ccef0>,
#  'слозный': <gensim.models.keyedvectors.Vocab at 0x15721b97a58>,
#  'nennt': <gensim.models.keyedvectors.Vocab at 0x1571e840e80>,
#  'цвето': <gensim.models.keyedvectors.Vocab at 0x1577d066240>,
#  'птол': <gensim.models.keyedvectors.Vocab at 0x157206224a8>,
# ...
#  'буденновка': <gensim.models.keyedvectors.Vocab at 0x1577c080eb8>,
#  'зачэм': <gensim.models.keyedvectors.Vocab at 0x1577bfa48d0>,
#  'грелли': <gensim.models.keyedvectors.Vocab at 0x15778254518>,
#  'эдельвакса': <gensim.models.keyedvectors.Vocab at 0x1571c529710>,
#  'баклуши': <gensim.models.keyedvectors.Vocab at 0x157799f3128>,
#  'пейчев': <gensim.models.keyedvectors.Vocab at 0x1577e4c6828>,
#  'геообъект': <gensim.models.keyedvectors.Vocab at 0x1577ca93908>,
#  'приспособленчество': <gensim.models.keyedvectors.Vocab at 0x15779deb080>,
#  'водоупор': <gensim.models.keyedvectors.Vocab at 0x15779c5bcc0>,
#  'лчэ': <gensim.models.keyedvectors.Vocab at 0x1571ca225c0>,
#  'внебытовой': <gensim.models.keyedvectors.Vocab at 0x1577e464f60>,
#  'полушутя': <gensim.models.keyedvectors.Vocab at 0x1577972d470>,
#  'стихотворный': <gensim.models.keyedvectors.Vocab at 0x15777f8dcc0>,
#  'удаваться': <gensim.models.keyedvectors.Vocab at 0x15777c31400>,
#  'семъя': <gensim.models.keyedvectors.Vocab at 0x1571ecfe4a8>,
#  'прийма': <gensim.models.keyedvectors.Vocab at 0x1577ce17320>,
#  'аверьянов': <gensim.models.keyedvectors.Vocab at 0x15779d6a7f0>,
#  'завмуза': <gensim.models.keyedvectors.Vocab at 0x1577f2040f0>,
#  'уск': <gensim.models.keyedvectors.Vocab at 0x1577c401630>,
#  'золка': <gensim.models.keyedvectors.Vocab at 0x1571e6da588>,
#  'бэссэ': <gensim.models.keyedvectors.Vocab at 0x1571e01f908>,
#  'межколесный': <gensim.models.keyedvectors.Vocab at 0x1577cd07cf8>,
#  'чикалка': <gensim.models.keyedvectors.Vocab at 0x1577fc2b4e0>,
#  'гонкур': <gensim.models.keyedvectors.Vocab at 0x1577a1508d0>,
#  'уступать': <gensim.models.keyedvectors.Vocab at 0x15777cb96a0>,
#  'мариенплац': <gensim.models.keyedvectors.Vocab at 0x1571e36b780>,
#  'антимузыка': <gensim.models.keyedvectors.Vocab at 0x1571c7e7128>,
#  'каррраул': <gensim.models.keyedvectors.Vocab at 0x1577f8cd9e8>,
#  'сонатный': <gensim.models.keyedvectors.Vocab at 0x1577c1a6a20>,
#  'маскулинная': <gensim.models.keyedvectors.Vocab at 0x1571cb42c88>,
#  'платежный': <gensim.models.keyedvectors.Vocab at 0x15778183cc0>,
#  'ссылочка': <gensim.models.keyedvectors.Vocab at 0x1577a147160>,
#  'планеангар': <gensim.models.keyedvectors.Vocab at 0x1571e0db128>,
#  'отпугивать': <gensim.models.keyedvectors.Vocab at 0x157780f96a0>,
#  'разупрочнение': <gensim.models.keyedvectors.Vocab at 0x1577c8466d8>,
#  'гутуевский': <gensim.models.keyedvectors.Vocab at 0x1577c4e3240>,
#  'рубрук': <gensim.models.keyedvectors.Vocab at 0x1577f4564e0>,
#  'пированьице': <gensim.models.keyedvectors.Vocab at 0x1571c671128>,
#  'штабель': <gensim.models.keyedvectors.Vocab at 0x1577808a7b8>,
#  'кафинькин': <gensim.models.keyedvectors.Vocab at 0x1577adbc860>,
#  'fang': <gensim.models.keyedvectors.Vocab at 0x1577f3b9898>,
#  'айдер': <gensim.models.keyedvectors.Vocab at 0x1577f68ea58>,
#  'ремонтантный': <gensim.models.keyedvectors.Vocab at 0x1577a15ccf8>,
#  'агеев': <gensim.models.keyedvectors.Vocab at 0x1577826b358>,
#  'бенгалия': <gensim.models.keyedvectors.Vocab at 0x1577a6197f0>,
#  'лажский': <gensim.models.keyedvectors.Vocab at 0x1571bea9b70>,
#  'отрожденный': <gensim.models.keyedvectors.Vocab at 0x1571c69e048>,
#  'прокопенка': <gensim.models.keyedvectors.Vocab at 0x1571c047198>,
#  'dobrava': <gensim.models.keyedvectors.Vocab at 0x1577cd29550>,
#  'солонцеватость': <gensim.models.keyedvectors.Vocab at 0x1571c85bcf8>,
#  'хрущев': <gensim.models.keyedvectors.Vocab at 0x15777d026d8>,
#  'толстолобик': <gensim.models.keyedvectors.Vocab at 0x1577a142da0>,
#  'угловский': <gensim.models.keyedvectors.Vocab at 0x1571bcc06a0>,
#  'рериховский': <gensim.models.keyedvectors.Vocab at 0x1577a77e2b0>,
#  'возопить': <gensim.models.keyedvectors.Vocab at 0x157785f76d8>,
#  'джемсский': <gensim.models.keyedvectors.Vocab at 0x1571bccaf60>,
#  'вакса': <gensim.models.keyedvectors.Vocab at 0x157784dc2e8>,
#  'medicod': <gensim.models.keyedvectors.Vocab at 0x1571c2f79e8>,
#  'семинома': <gensim.models.keyedvectors.Vocab at 0x1577cd24b00>,
#  'ашкенази': <gensim.models.keyedvectors.Vocab at 0x1577a2f7f28>,
#  'промодулировать': <gensim.models.keyedvectors.Vocab at 0x1577a8e8b00>,
#  'госпродкомиссия': <gensim.models.keyedvectors.Vocab at 0x1571c896390>,
#  'прекраснодушие': <gensim.models.keyedvectors.Vocab at 0x15779e9ad30>,
#  'маскат': <gensim.models.keyedvectors.Vocab at 0x1577aa29198>,
#  'аутичность': <gensim.models.keyedvectors.Vocab at 0x1577fc0fd30>,
#  'гексагон': <gensim.models.keyedvectors.Vocab at 0x1577e244860>,
#  'присовокупление': <gensim.models.keyedvectors.Vocab at 0x1577c29e780>,
#  'макаркин': <gensim.models.keyedvectors.Vocab at 0x15779eb4390>,
#  'раскричаться': <gensim.models.keyedvectors.Vocab at 0x15779905860>,
#  'пальма': <gensim.models.keyedvectors.Vocab at 0x15777deec18>,
#  'рахимчик': <gensim.models.keyedvectors.Vocab at 0x1577f518518>,
#  'нотабена': <gensim.models.keyedvectors.Vocab at 0x1577e48cf98>,
#  'тонмас': <gensim.models.keyedvectors.Vocab at 0x157206307b8>,
#  'сакас': <gensim.models.keyedvectors.Vocab at 0x1571e4a5e80>,
#  'здря': <gensim.models.keyedvectors.Vocab at 0x1577a551550>,
#  'рентгенография': <gensim.models.keyedvectors.Vocab at 0x1577a7d40b8>,
#  'затрещать': <gensim.models.keyedvectors.Vocab at 0x15777fe2828>,
#  'тренерша': <gensim.models.keyedvectors.Vocab at 0x1577ac23b38>,
#  'провович': <gensim.models.keyedvectors.Vocab at 0x1571cac84e0>,
#  'охлестать': <gensim.models.keyedvectors.Vocab at 0x1571cc8f208>,
#  'выигрышно': <gensim.models.keyedvectors.Vocab at 0x1577a701588>,
#  'pavor': <gensim.models.keyedvectors.Vocab at 0x1577ffa3908>,
#  'гагарочек': <gensim.models.keyedvectors.Vocab at 0x1571e255898>,
#  'сводиться': <gensim.models.keyedvectors.Vocab at 0x15777d2d9e8>,
#  'ħau̯xor': <gensim.models.keyedvectors.Vocab at 0x157207124a8>,
#  'перчихин': <gensim.models.keyedvectors.Vocab at 0x157799b6240>,
#  'рысиный': <gensim.models.keyedvectors.Vocab at 0x1571c6c92b0>,
#  'phyllon': <gensim.models.keyedvectors.Vocab at 0x15720870cf8>,
#  'workshops': <gensim.models.keyedvectors.Vocab at 0x15721ad3d68>,
#  'майкин': <gensim.models.keyedvectors.Vocab at 0x1577c00c748>,
#  'полока': <gensim.models.keyedvectors.Vocab at 0x1571bd84518>,
#  'аннибала': <gensim.models.keyedvectors.Vocab at 0x15779cbb898>,
#  'подпроблема': <gensim.models.keyedvectors.Vocab at 0x1571c8894a8>,
#  'эстонский': <gensim.models.keyedvectors.Vocab at 0x15777f43b38>,
#  'бормотушный': <gensim.models.keyedvectors.Vocab at 0x1571ed037b8>,
#  'богачка': <gensim.models.keyedvectors.Vocab at 0x15779f2d2e8>,
#  'забурдаев': <gensim.models.keyedvectors.Vocab at 0x15721867668>,
#  'стукалочка': <gensim.models.keyedvectors.Vocab at 0x1577cf36c50>,
#  'наградной': <gensim.models.keyedvectors.Vocab at 0x15779785be0>,
#  'должецкий': <gensim.models.keyedvectors.Vocab at 0x1577ac31160>,
#  'попутничество': <gensim.models.keyedvectors.Vocab at 0x1577ce6aef0>,
#  'гринчик': <gensim.models.keyedvectors.Vocab at 0x1577cd072b0>,
#  'досекать': <gensim.models.keyedvectors.Vocab at 0x157207bc198>,
#  'пятисекундный': <gensim.models.keyedvectors.Vocab at 0x1577e550400>,
#  'швайне': <gensim.models.keyedvectors.Vocab at 0x1571c3379e8>,
#  'переобмундировывать': <gensim.models.keyedvectors.Vocab at 0x1571c23d518>,
#  'адальберт': <gensim.models.keyedvectors.Vocab at 0x1577a3818d0>,
#  'роуд': <gensim.models.keyedvectors.Vocab at 0x15779dc0c50>,
#  'смеживать': <gensim.models.keyedvectors.Vocab at 0x1571c5800b8>,
#  'ophir': <gensim.models.keyedvectors.Vocab at 0x1571e00fb38>,
#  'киреевка': <gensim.models.keyedvectors.Vocab at 0x1577c60ee48>,
#  'ингэгрук': <gensim.models.keyedvectors.Vocab at 0x1571bdb0128>,
#  'теплоемкость': <gensim.models.keyedvectors.Vocab at 0x157799303c8>,
#  'дергунец': <gensim.models.keyedvectors.Vocab at 0x1571bcd8198>,
#  'беан': <gensim.models.keyedvectors.Vocab at 0x1571bf809b0>,
#  'элиос': <gensim.models.keyedvectors.Vocab at 0x1571bf4c7f0>,
#  'благосмыслие': <gensim.models.keyedvectors.Vocab at 0x1577fcf73c8>,
#  'хомутников': <gensim.models.keyedvectors.Vocab at 0x1572065c6a0>,
#  'ложить': <gensim.models.keyedvectors.Vocab at 0x1577a0710b8>,
#  'клеить': <gensim.models.keyedvectors.Vocab at 0x157781dc4a8>,
#  'трецек': <gensim.models.keyedvectors.Vocab at 0x1571e737518>,
#  'запереть': <gensim.models.keyedvectors.Vocab at 0x1571c3cc160>,
#  'лесопильня': <gensim.models.keyedvectors.Vocab at 0x1577a6800f0>,
#  'продотрядовец': <gensim.models.keyedvectors.Vocab at 0x1577cd324e0>,
#  'изваянность': <gensim.models.keyedvectors.Vocab at 0x1571df13c50>,
#  'джамби': <gensim.models.keyedvectors.Vocab at 0x15779f297f0>,
#  'псевдогреческий': <gensim.models.keyedvectors.Vocab at 0x1571eb777f0>,
#  'малотравматичный': <gensim.models.keyedvectors.Vocab at 0x1577adb7c88>,
#  'хроматографлять': <gensim.models.keyedvectors.Vocab at 0x1571e2550b8>,
#  'амперян': <gensim.models.keyedvectors.Vocab at 0x1577c6300f0>,
#  'шаушпиллер': <gensim.models.keyedvectors.Vocab at 0x1577cdef828>,
#  'робертович': <gensim.models.keyedvectors.Vocab at 0x15779ffc518>,
#  'припарки': <gensim.models.keyedvectors.Vocab at 0x1577c4c7d30>,
#  'голять': <gensim.models.keyedvectors.Vocab at 0x1577f37f160>,
#  'заспинный': <gensim.models.keyedvectors.Vocab at 0x15779b1ee80>,
#  'заготпушнина': <gensim.models.keyedvectors.Vocab at 0x1577d11f048>,
#  'мелюзеевец': <gensim.models.keyedvectors.Vocab at 0x1571dfa3470>,
#  'фактурный': <gensim.models.keyedvectors.Vocab at 0x15779db0b00>,
#  'свежемобилизованный': <gensim.models.keyedvectors.Vocab at 0x1571e48e0b8>,
#  'вустя': <gensim.models.keyedvectors.Vocab at 0x157205b5630>,
#  'писах': <gensim.models.keyedvectors.Vocab at 0x1571c974ac8>,
#  'колюбакин': <gensim.models.keyedvectors.Vocab at 0x1577a3eb080>,
#  'саперлипопеть': <gensim.models.keyedvectors.Vocab at 0x15779c17f60>,
#  'викрамасингх': <gensim.models.keyedvectors.Vocab at 0x1571e2c1748>,
#  'семя': <gensim.models.keyedvectors.Vocab at 0x15777cf30b8>,
#  'конопатик': <gensim.models.keyedvectors.Vocab at 0x1571c533be0>,
#  'балдабрек': <gensim.models.keyedvectors.Vocab at 0x1577c7d9208>,
#  'шифроваться': <gensim.models.keyedvectors.Vocab at 0x1577bf9ae80>,
#  'комплиментика': <gensim.models.keyedvectors.Vocab at 0x1571dcff1d0>,
#  'дикозавр': <gensim.models.keyedvectors.Vocab at 0x1577a9676a0>,
#  'дидюлить': <gensim.models.keyedvectors.Vocab at 0x1577f7ab668>,
#  'автоколебательный': <gensim.models.keyedvectors.Vocab at 0x1577bed1860>,
#  'петух': <gensim.models.keyedvectors.Vocab at 0x15777d6c7f0>,
#  'абстракционизм': <gensim.models.keyedvectors.Vocab at 0x15779ff2278>,
#  'oв': <gensim.models.keyedvectors.Vocab at 0x1577a9f2860>,
#  'ворище': <gensim.models.keyedvectors.Vocab at 0x1577a9a2128>,
#  'зеленоплодный': <gensim.models.keyedvectors.Vocab at 0x1577ca0d240>,
#  'обкладывать': <gensim.models.keyedvectors.Vocab at 0x15777eee208>,
#  'жилкооперация': <gensim.models.keyedvectors.Vocab at 0x1577bec33c8>,
#  'tam': <gensim.models.keyedvectors.Vocab at 0x1577c3ae0f0>,
#  'учительский': <gensim.models.keyedvectors.Vocab at 0x15778129748>,
#  'units': <gensim.models.keyedvectors.Vocab at 0x1571bce3b38>,
#  'дарина': <gensim.models.keyedvectors.Vocab at 0x1571c8afba8>,
#  'все-таки': <gensim.models.keyedvectors.Vocab at 0x15777c31278>,
#  'ломик': <gensim.models.keyedvectors.Vocab at 0x157798ec320>,
#  'радхакришнан': <gensim.models.keyedvectors.Vocab at 0x1577c7c1438>,
#  'бремсберг': <gensim.models.keyedvectors.Vocab at 0x1577be314e0>,
#  'калль': <gensim.models.keyedvectors.Vocab at 0x1571e00ba58>,
#  'фотопериодизм': <gensim.models.keyedvectors.Vocab at 0x1577c9af860>,
#  'экус': <gensim.models.keyedvectors.Vocab at 0x1577d112d68>,
#  'сарпа': <gensim.models.keyedvectors.Vocab at 0x1577d129eb8>,
#  'honoris': <gensim.models.keyedvectors.Vocab at 0x15779a83ef0>,
#  'забивание': <gensim.models.keyedvectors.Vocab at 0x1577a0162e8>,
#  'кычет': <gensim.models.keyedvectors.Vocab at 0x1577add40f0>,
#  'досиня': <gensim.models.keyedvectors.Vocab at 0x1577a7baba8>,
#  'менделеевка': <gensim.models.keyedvectors.Vocab at 0x1577be6da90>,
#  'педиатр': <gensim.models.keyedvectors.Vocab at 0x15778646f28>,
#  'жезл': <gensim.models.keyedvectors.Vocab at 0x15778086898>,
#  'телепремьера': <gensim.models.keyedvectors.Vocab at 0x15721b764e0>,
#  'forumsport': <gensim.models.keyedvectors.Vocab at 0x1571be2f4a8>,
#  'гарпушка': <gensim.models.keyedvectors.Vocab at 0x1571e80cd68>,
#  'шагеев': <gensim.models.keyedvectors.Vocab at 0x1577a8adb38>,
#  'ser': <gensim.models.keyedvectors.Vocab at 0x1577be3bba8>,
#  'победова': <gensim.models.keyedvectors.Vocab at 0x1571bd456d8>,
#  'сущевская': <gensim.models.keyedvectors.Vocab at 0x1571cbd8cc0>,
#  'ааль': <gensim.models.keyedvectors.Vocab at 0x1577fa33780>,
#  'твердосплавный': <gensim.models.keyedvectors.Vocab at 0x1577a7b6470>,
#  'перегоночный': <gensim.models.keyedvectors.Vocab at 0x1577cafb780>,
#  'карачаевск': <gensim.models.keyedvectors.Vocab at 0x1577f7827b8>,
#  'самокрутка': <gensim.models.keyedvectors.Vocab at 0x15778594a58>,
#  'междусобойный': <gensim.models.keyedvectors.Vocab at 0x1571c7adbe0>,
#  'недеятельный': <gensim.models.keyedvectors.Vocab at 0x1577a4429e8>,
#  'танконепроходимый': <gensim.models.keyedvectors.Vocab at 0x1571cc0c048>,
#  'транспортировка': <gensim.models.keyedvectors.Vocab at 0x15777f09908>,
#  'барклай': <gensim.models.keyedvectors.Vocab at 0x157782c5c88>,
#  'елян': <gensim.models.keyedvectors.Vocab at 0x1577c891320>,
#  'поклоно': <gensim.models.keyedvectors.Vocab at 0x1577cb2f780>,
#  'мэлэхэ': <gensim.models.keyedvectors.Vocab at 0x1577c9831d0>,
#  'ливп': <gensim.models.keyedvectors.Vocab at 0x1577f2db278>,
#  'книгы': <gensim.models.keyedvectors.Vocab at 0x1577ac62048>,
#  'недоклеивать': <gensim.models.keyedvectors.Vocab at 0x1571c156978>,
#  'жиго': <gensim.models.keyedvectors.Vocab at 0x1571ccc6588>,
#  'эльдорадио': <gensim.models.keyedvectors.Vocab at 0x1577e50c780>,
#  'умопомрачительность': <gensim.models.keyedvectors.Vocab at 0x1571cbb52e8>,
#  'древнескандинавский': <gensim.models.keyedvectors.Vocab at 0x1577cb67cf8>,
#  'изгой': <gensim.models.keyedvectors.Vocab at 0x1577844e048>,
#  'лесонаучный': <gensim.models.keyedvectors.Vocab at 0x1577abdab70>,
#  'роммелевский': <gensim.models.keyedvectors.Vocab at 0x1577f7a0a90>,
#  'зееловский': <gensim.models.keyedvectors.Vocab at 0x1577cccd240>,
#  'подделыватель': <gensim.models.keyedvectors.Vocab at 0x1577a01f828>,
#  'мультатуля': <gensim.models.keyedvectors.Vocab at 0x1577c0c1f98>,
#  'поверху': <gensim.models.keyedvectors.Vocab at 0x157785855f8>,
#  'сакманщица': <gensim.models.keyedvectors.Vocab at 0x1577a8f6860>,
#  'солдатово': <gensim.models.keyedvectors.Vocab at 0x1577caba898>,
#  'хипповатый': <gensim.models.keyedvectors.Vocab at 0x1577f3749e8>,
#  'procedure': <gensim.models.keyedvectors.Vocab at 0x1577c9f5710>,
#  'smoking': <gensim.models.keyedvectors.Vocab at 0x1577cec3710>,
#  'сподин': <gensim.models.keyedvectors.Vocab at 0x1577fc62fd0>,
#  'иммуноанализ': <gensim.models.keyedvectors.Vocab at 0x1571cc8b8d0>,
#  'основное': <gensim.models.keyedvectors.Vocab at 0x15777dc5d30>,
#  'крамлинг': <gensim.models.keyedvectors.Vocab at 0x1577abed9b0>,
#  'лавернь': <gensim.models.keyedvectors.Vocab at 0x1577c596400>,
#  'печенюк': <gensim.models.keyedvectors.Vocab at 0x1577ad0d588>,
#  'анкт': <gensim.models.keyedvectors.Vocab at 0x1577abed7f0>,
#  'убогенький': <gensim.models.keyedvectors.Vocab at 0x1577e20a978>,
#  'зодиакальный': <gensim.models.keyedvectors.Vocab at 0x1577a245ef0>,
#  'контрснайперский': <gensim.models.keyedvectors.Vocab at 0x1571c8cc6a0>,
#  'юсин': <gensim.models.keyedvectors.Vocab at 0x1577a519eb8>,
#  'бадон': <gensim.models.keyedvectors.Vocab at 0x157219d7160>,
#  'цкбм': <gensim.models.keyedvectors.Vocab at 0x1577fcd0240>,
#  'галургия': <gensim.models.keyedvectors.Vocab at 0x1577bf8b278>,
#  'феоктист': <gensim.models.keyedvectors.Vocab at 0x157783d72b0>,
#  'микель': <gensim.models.keyedvectors.Vocab at 0x15779e85ba8>,
#  'правосол': <gensim.models.keyedvectors.Vocab at 0x1571e6c4ef0>,
#  'шарыпово': <gensim.models.keyedvectors.Vocab at 0x1577f438978>,
#  'бублайтис': <gensim.models.keyedvectors.Vocab at 0x1577cc98668>,
#  'шаршава': <gensim.models.keyedvectors.Vocab at 0x1577a1420b8>,
#  'мулен': <gensim.models.keyedvectors.Vocab at 0x15778346f60>,
#  'малоопрятный': <gensim.models.keyedvectors.Vocab at 0x1571e535978>,
#  ...}

# %% [markdown]
# #### Посмотрим, как с ней обращаться

# %% [markdown]
# Можно посмотреть наиболее похожие на одни и наиболее непохожие на другие слова. Попробуйте свойтсва векторов word2vec и подумать какие слова нужно послать на вход, чтобы получить на выходе слова "школа",  "машинное", "обучение"

# %%
model_word2vec.most_similar(positive=['учеба','гимназия','занятие'],
                            negative=[], topn=3)
# Out:
# [('школа', 0.5777938365936279),
#  ('курсы', 0.5749321579933167),
#  ('обучение', 0.5554687976837158)]

# %%
model_word2vec.most_similar(positive=['корабль', 'летать'], negative=['плавать'], topn=3)
# Out:
# [('самолет', 0.5802854299545288),
#  ('судно', 0.533637523651123),
#  ('дирижабль', 0.5083058476448059)]

# %%
model_word2vec.most_similar(positive=['шахтер'], negative=['грязь'], topn=3)
# Out:
# [('горняк', 0.3543156683444977),
#  ('ударник', 0.336887001991272),
#  ('металлург', 0.3220180869102478)]

# %%
model_word2vec.most_similar(positive=['учение', 'тьма'], negative=['свет'], topn=3)
# Out:
# [('мрак', 0.4193800687789917),
#  ('догмат', 0.38442569971084595),
#  ('философия', 0.3840946555137634)]

# %% [markdown]
# Еще есть прикольная функция, которая выводит слово, лишнее в строке. Попробуйте придумать пример, который word2vec не взломает

# %%
model_word2vec.doesnt_match("содовая жиле сок морс".split())
# Out:
# 'содовая'

# %% [markdown]
# Функция, которая выводит сходство между словами.  С ее помощью можно понимать значение слова нефть

# %%
print(model_word2vec.similarity('нефть', 'газ'))
print(model_word2vec.similarity('нефть', 'вода'))
print(model_word2vec.similarity('нефть', 'водка'))
print(model_word2vec.similarity('нефть', 'духи'))
print(model_word2vec.similarity('нефть', 'компот'))
# Out:
# 0.401784575535
# 0.246770688846
# 0.0859883239246
# 0.0297233953559
# 0.014373137645

# %% [markdown]
# Или смотреть, где в России больше нефти

# %%
print(model_word2vec.similarity('нефть', 'чечня'))
print(model_word2vec.similarity('нефть', 'якутск'))
print(model_word2vec.similarity('нефть', 'москва'))
print(model_word2vec.similarity('нефть', 'саратов'))
print(model_word2vec.similarity('нефть', 'сибирь'))
# Out:
# 0.102318135805
# 0.0374594075176
# 0.00765520311232
# 0.00437990603761
# 0.0863051911584

# %% [markdown]
# ### Теперь давайте обучим собственную модель

# %% [markdown]
#  В качестве обучающего корпуса возьмем новости по 20 темам

# %%
from sklearn.datasets import fetch_20newsgroups
train_all = fetch_20newsgroups(subset='train')
print(train_all.target_names, " - 20 возможных тем")

dataset = fetch_20newsgroups(
    subset='train', 
    categories=['comp.sys.mac.hardware', 'soc.religion.christian', 'rec.sport.hockey'])

dataset.data[0].split()
# Out:
# ['alt.atheism', 'comp.graphics', 'comp.os.ms-windows.misc', 'comp.sys.ibm.pc.hardware', 'comp.sys.mac.hardware', 'comp.windows.x', 'misc.forsale', 'rec.autos', 'rec.motorcycles', 'rec.sport.baseball', 'rec.sport.hockey', 'sci.crypt', 'sci.electronics', 'sci.med', 'sci.space', 'soc.religion.christian', 'talk.politics.guns', 'talk.politics.mideast', 'talk.politics.misc', 'talk.religion.misc']  - 20 возможных тем
# ['From:',
#  'erik@cheshire.oxy.edu',
#  '(Erik',
#  'Adams)',
#  'Subject:',
#  'HELP!!',
#  'My',
#  'Macintosh',
#  '"luggable"',
#  'has',
#  'lines',
#  'on',
#  'its',
#  'screen!',
#  'Organization:',
#  'Occidental',
#  'College,',
#  'Los',
#  'Angeles,',
#  'CA',
#  '90041',
#  'USA.',
#  'Distribution:',
#  'comp',
#  'Lines:',
#  '20',
#  'Okay,',
#  'I',
#  "don't",
#  'use',
#  'it',
#  'very',
#  'much,',
#  'but',
#  'I',
#  'would',
#  'like',
#  'for',
#  'it',
#  'to',
#  'keep',
#  'working',
#  'correctly,',
#  'at',
#  'least',
#  'as',
#  'long',
#  'as',
#  'Apple',
#  'continues',
#  'to',
#  'make',
#  'System',
#  'software',
#  'that',
#  'will',
#  'run',
#  'on',
#  'it,',
#  'if',
#  'slowly',
#  ':-)',
#  'Here',
#  'is',
#  'the',
#  'problem:',
#  'When',
#  'the',
#  'screen',
#  'is',
#  'tilted',
#  'too',
#  'far',
#  'back,',
#  'vertical',
#  'lines',
#  'appear',
#  'on',
#  'the',
#  'screen.',
#  'They',
#  'are',
#  'every',
#  '10',
#  'pixels',
#  'or',
#  'so,',
#  'and',
#  'seem',
#  'to',
#  'be',
#  'affected',
#  'somewhat',
#  'by',
#  'opening',
#  'windows',
#  'and',
#  'pulling',
#  'down',
#  'menus.',
#  'It',
#  'looks',
#  'to',
#  'a',
#  'semi-technical',
#  'person',
#  'like',
#  'there',
#  'is',
#  'a',
#  'loose',
#  'connection',
#  'between',
#  'the',
#  'screen',
#  'and',
#  'the',
#  'rest',
#  'of',
#  'the',
#  'computer.',
#  'I',
#  'am',
#  'open',
#  'to',
#  'suggestions',
#  'that',
#  'do',
#  'not',
#  'involve',
#  'buying',
#  'a',
#  'new',
#  'computer,',
#  'or',
#  'taking',
#  'this',
#  'one',
#  'to',
#  'the',
#  'shop.',
#  'I',
#  'would',
#  'also',
#  'like',
#  'to',
#  'not',
#  'have',
#  'to',
#  'buy',
#  'one',
#  'of',
#  'Larry',
#  "Pina's",
#  'books.',
#  'I',
#  'like',
#  'Larry,',
#  'but',
#  "I'm",
#  'not',
#  'sure',
#  'I',
#  'feel',
#  'strongly',
#  'enough',
#  'about',
#  'the',
#  'computer',
#  'to',
#  'buy',
#  'a',
#  'service',
#  'manual',
#  'for',
#  'it.',
#  'On',
#  'a',
#  'related',
#  'note:',
#  'what',
#  'does',
#  'the',
#  'monitor',
#  'connector',
#  'connect',
#  'to?',
#  'Erik']

# %%
x = dataset.data[0]
dict_rus = ''.join(x)
translator = str.maketrans({key: ' ' for key in string.punctuation.replace('/', '').replace('-', '') + string.digits + '№'})
dict_rus =dict_rus.translate(translator).lower()
dict_rus.split()
# Out:
# ['from',
#  'erik',
#  'cheshire',
#  'oxy',
#  'edu',
#  'erik',
#  'adams',
#  'subject',
#  'help',
#  'my',
#  'macintosh',
#  'luggable',
#  'has',
#  'lines',
#  'on',
#  'its',
#  'screen',
#  'organization',
#  'occidental',
#  'college',
#  'los',
#  'angeles',
#  'ca',
#  'usa',
#  'distribution',
#  'comp',
#  'lines',
#  'okay',
#  'i',
#  'don',
#  't',
#  'use',
#  'it',
#  'very',
#  'much',
#  'but',
#  'i',
#  'would',
#  'like',
#  'for',
#  'it',
#  'to',
#  'keep',
#  'working',
#  'correctly',
#  'at',
#  'least',
#  'as',
#  'long',
#  'as',
#  'apple',
#  'continues',
#  'to',
#  'make',
#  'system',
#  'software',
#  'that',
#  'will',
#  'run',
#  'on',
#  'it',
#  'if',
#  'slowly',
#  '-',
#  'here',
#  'is',
#  'the',
#  'problem',
#  'when',
#  'the',
#  'screen',
#  'is',
#  'tilted',
#  'too',
#  'far',
#  'back',
#  'vertical',
#  'lines',
#  'appear',
#  'on',
#  'the',
#  'screen',
#  'they',
#  'are',
#  'every',
#  'pixels',
#  'or',
#  'so',
#  'and',
#  'seem',
#  'to',
#  'be',
#  'affected',
#  'somewhat',
#  'by',
#  'opening',
#  'windows',
#  'and',
#  'pulling',
#  'down',
#  'menus',
#  'it',
#  'looks',
#  'to',
#  'a',
#  'semi-technical',
#  'person',
#  'like',
#  'there',
#  'is',
#  'a',
#  'loose',
#  'connection',
#  'between',
#  'the',
#  'screen',
#  'and',
#  'the',
#  'rest',
#  'of',
#  'the',
#  'computer',
#  'i',
#  'am',
#  'open',
#  'to',
#  'suggestions',
#  'that',
#  'do',
#  'not',
#  'involve',
#  'buying',
#  'a',
#  'new',
#  'computer',
#  'or',
#  'taking',
#  'this',
#  'one',
#  'to',
#  'the',
#  'shop',
#  'i',
#  'would',
#  'also',
#  'like',
#  'to',
#  'not',
#  'have',
#  'to',
#  'buy',
#  'one',
#  'of',
#  'larry',
#  'pina',
#  's',
#  'books',
#  'i',
#  'like',
#  'larry',
#  'but',
#  'i',
#  'm',
#  'not',
#  'sure',
#  'i',
#  'feel',
#  'strongly',
#  'enough',
#  'about',
#  'the',
#  'computer',
#  'to',
#  'buy',
#  'a',
#  'service',
#  'manual',
#  'for',
#  'it',
#  'on',
#  'a',
#  'related',
#  'note',
#  'what',
#  'does',
#  'the',
#  'monitor',
#  'connector',
#  'connect',
#  'to',
#  'erik']

# %% [markdown]
# Предобраотаем эти новости. Выкинем цифры, знаки пунктуации, переведем в нижний регистр, разобьем на слова.
# Нормализуйте слова, например, с помощью модуля nltk (или используйте любой другой способ на ваш выбор)

# %%
import string 
def normalize(x):
    dict_rus = ''.join(x)
    translator = str.maketrans({key: ' ' for key in string.punctuation.replace('/', '').replace('-', '') + string.digits + '№'})
    dict_rus =dict_rus.translate(translator).lower()
    x_preprocessed = dict_rus.split()
    #<Ваш код>
    return(x_preprocessed)

# %%
# Применяем фунции предобработки к нашим новостям
data_normalized = [normalize(new) for new in tqdm(dataset.data)]
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 1777/1777 [00:00<00:00, 14211.09it/s]

# %%
data_normalized[0]
# Out:
# ['from',
#  'erik',
#  'cheshire',
#  'oxy',
#  'edu',
#  'erik',
#  'adams',
#  'subject',
#  'help',
#  'my',
#  'macintosh',
#  'luggable',
#  'has',
#  'lines',
#  'on',
#  'its',
#  'screen',
#  'organization',
#  'occidental',
#  'college',
#  'los',
#  'angeles',
#  'ca',
#  'usa',
#  'distribution',
#  'comp',
#  'lines',
#  'okay',
#  'i',
#  'don',
#  't',
#  'use',
#  'it',
#  'very',
#  'much',
#  'but',
#  'i',
#  'would',
#  'like',
#  'for',
#  'it',
#  'to',
#  'keep',
#  'working',
#  'correctly',
#  'at',
#  'least',
#  'as',
#  'long',
#  'as',
#  'apple',
#  'continues',
#  'to',
#  'make',
#  'system',
#  'software',
#  'that',
#  'will',
#  'run',
#  'on',
#  'it',
#  'if',
#  'slowly',
#  '-',
#  'here',
#  'is',
#  'the',
#  'problem',
#  'when',
#  'the',
#  'screen',
#  'is',
#  'tilted',
#  'too',
#  'far',
#  'back',
#  'vertical',
#  'lines',
#  'appear',
#  'on',
#  'the',
#  'screen',
#  'they',
#  'are',
#  'every',
#  'pixels',
#  'or',
#  'so',
#  'and',
#  'seem',
#  'to',
#  'be',
#  'affected',
#  'somewhat',
#  'by',
#  'opening',
#  'windows',
#  'and',
#  'pulling',
#  'down',
#  'menus',
#  'it',
#  'looks',
#  'to',
#  'a',
#  'semi-technical',
#  'person',
#  'like',
#  'there',
#  'is',
#  'a',
#  'loose',
#  'connection',
#  'between',
#  'the',
#  'screen',
#  'and',
#  'the',
#  'rest',
#  'of',
#  'the',
#  'computer',
#  'i',
#  'am',
#  'open',
#  'to',
#  'suggestions',
#  'that',
#  'do',
#  'not',
#  'involve',
#  'buying',
#  'a',
#  'new',
#  'computer',
#  'or',
#  'taking',
#  'this',
#  'one',
#  'to',
#  'the',
#  'shop',
#  'i',
#  'would',
#  'also',
#  'like',
#  'to',
#  'not',
#  'have',
#  'to',
#  'buy',
#  'one',
#  'of',
#  'larry',
#  'pina',
#  's',
#  'books',
#  'i',
#  'like',
#  'larry',
#  'but',
#  'i',
#  'm',
#  'not',
#  'sure',
#  'i',
#  'feel',
#  'strongly',
#  'enough',
#  'about',
#  'the',
#  'computer',
#  'to',
#  'buy',
#  'a',
#  'service',
#  'manual',
#  'for',
#  'it',
#  'on',
#  'a',
#  'related',
#  'note',
#  'what',
#  'does',
#  'the',
#  'monitor',
#  'connector',
#  'connect',
#  'to',
#  'erik']

# %% [markdown]
# Все, обучающий корпус готов!

# %%
# импортируем модули, настраиваем логирование
import gensim, logging

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
sentences = data_normalized
model = gensim.models.Word2Vec(sentences, min_count=1)
# Out:
# 2017-11-17 00:00:47,646 : INFO : collecting all words and their counts
# 2017-11-17 00:00:47,646 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2017-11-17 00:00:47,756 : INFO : collected 25825 word types from a corpus of 508463 raw words and 1777 sentences
# 2017-11-17 00:00:47,756 : INFO : Loading a fresh vocabulary
# 2017-11-17 00:00:47,865 : INFO : min_count=1 retains 25825 unique words (100% of original 25825, drops 0)
# 2017-11-17 00:00:47,865 : INFO : min_count=1 leaves 508463 word corpus (100% of original 508463, drops 0)
# 2017-11-17 00:00:47,943 : INFO : deleting the raw counts dictionary of 25825 items
# 2017-11-17 00:00:47,943 : INFO : sample=0.001 downsamples 52 most-common words
# 2017-11-17 00:00:47,943 : INFO : downsampling leaves estimated 405784 word corpus (79.8% of prior 508463)
# 2017-11-17 00:00:47,943 : INFO : estimated required memory for 25825 words and 100 dimensions: 33572500 bytes
# 2017-11-17 00:00:48,021 : INFO : resetting layer weights
# 2017-11-17 00:00:48,318 : INFO : training model with 3 workers on 25825 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2017-11-17 00:00:49,318 : INFO : PROGRESS: at 53.18% examples, 1073734 words/s, in_qsize 5, out_qsize 0
# 2017-11-17 00:00:50,037 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2017-11-17 00:00:50,037 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2017-11-17 00:00:50,053 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2017-11-17 00:00:50,053 : INFO : training on 2542315 raw words (2028947 effective words) took 1.7s, 1168337 effective words/s

# %%
model = gensim.models.Word2Vec(iter=1)  # Задаем пустую модель, не натренированную
model.build_vocab(sentences)  # Строим словарь
model.train(sentences, total_examples=model.corpus_count, epochs=20)  # Тренируем модель
# Out:
# 2017-11-17 00:00:52,007 : INFO : collecting all words and their counts
# 2017-11-17 00:00:52,007 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2017-11-17 00:00:52,116 : INFO : collected 25825 word types from a corpus of 508463 raw words and 1777 sentences
# 2017-11-17 00:00:52,116 : INFO : Loading a fresh vocabulary
# 2017-11-17 00:00:52,147 : INFO : min_count=5 retains 7923 unique words (30% of original 25825, drops 17902)
# 2017-11-17 00:00:52,147 : INFO : min_count=5 leaves 477458 word corpus (93% of original 508463, drops 31005)
# 2017-11-17 00:00:52,178 : INFO : deleting the raw counts dictionary of 25825 items
# 2017-11-17 00:00:52,178 : INFO : sample=0.001 downsamples 54 most-common words
# 2017-11-17 00:00:52,178 : INFO : downsampling leaves estimated 371067 word corpus (77.7% of prior 477458)
# 2017-11-17 00:00:52,178 : INFO : estimated required memory for 7923 words and 100 dimensions: 10299900 bytes
# 2017-11-17 00:00:52,225 : INFO : resetting layer weights
# 2017-11-17 00:00:52,319 : INFO : training model with 3 workers on 7923 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2017-11-17 00:00:53,319 : INFO : PROGRESS: at 17.08% examples, 1264980 words/s, in_qsize 5, out_qsize 0
# 2017-11-17 00:00:54,335 : INFO : PROGRESS: at 34.27% examples, 1270453 words/s, in_qsize 4, out_qsize 1
# 2017-11-17 00:00:55,335 : INFO : PROGRESS: at 51.30% examples, 1266555 words/s, in_qsize 5, out_qsize 0
# 2017-11-17 00:00:56,335 : INFO : PROGRESS: at 70.46% examples, 1303702 words/s, in_qsize 5, out_qsize 0
# 2017-11-17 00:00:57,335 : INFO : PROGRESS: at 88.01% examples, 1301489 words/s, in_qsize 5, out_qsize 0
# 2017-11-17 00:00:58,007 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2017-11-17 00:00:58,007 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2017-11-17 00:00:58,023 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2017-11-17 00:00:58,023 : INFO : training on 10169260 raw words (7420754 effective words) took 5.7s, 1303590 effective words/s
# 7420754

# %% [markdown]
# Теперь давайте нарисуем слова из первой новости в нашем новом пространстве

# %%
# Берем слова из первой новости, достаем соостветствующие векторы, выбрасываем слова, для которых векторов нет. 
# Подумайте - как так могло получится, что нет векторов?
# Возможно, алгоритм убрал редкие слова.
labels = []
embeddings = []
data_to_tsne = [item for sublist in data_normalized[:20] for item in sublist]
for x in list(set(data_to_tsne)):
    try:
        embeddings.append(model[x])
        labels.append(x)
    except KeyError:
        continue

# %%
# Пишем функцию, которая будет нам все отрисовывать.
def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
    assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
    plt.figure(figsize=(18, 18))  # in inches
    for i, label in enumerate(labels):
        x, y = low_dim_embs[i, :]
        plt.scatter(x, y)
        plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')
    plt.show()
    #plt.savefig(filename)

# %%
# Сжимаем наше 100-мерное пространство в 2-х мерное
tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
plot_only = 300
low_dim_embs = tsne.fit_transform((embeddings[:plot_only]))

# %%
# Рисуем только первые 1000 слов

labels_to_draw = [labels[i] for i in range(plot_only)]
plot_with_labels(low_dim_embs, labels_to_draw)

# %% [markdown]
# ### Пункт 0
# Проделайте аналогичную отрисовку и сжатие векторов для предобученной модели (для этого скачайте бинарник по этой ссылке - https://code.google.com/archive/p/word2vec/ (файл GoogleNews-vectors-negative300) по аналогии с тем, как мы работали с русским корпусом). Сравните результаты

# %%
path_to_google = 'GoogleNews-vectors-negative300.bin'
model = gensim.models.KeyedVectors.load_word2vec_format(path_to_google, binary = True)
# Out:
# 2017-11-17 00:01:07,681 : INFO : loading projection weights from GoogleNews-vectors-negative300.bin
# 2017-11-17 00:02:11,253 : INFO : loaded (3000000, 300) matrix from GoogleNews-vectors-negative300.bin

# %%
labels = []
embeddings = []
data_to_tsne = [item for sublist in data_normalized[:20] for item in sublist]
for x in list(set(data_to_tsne)):
    try:
        embeddings.append(model[x])
        labels.append(x)
    except KeyError:
        continue

# %%
tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
plot_only = 1000
low_dim_embs = tsne.fit_transform((embeddings[:plot_only]))
labels_to_draw = [labels[i] for i in range(plot_only)]
plot_with_labels(low_dim_embs, labels_to_draw)

# %% [markdown]
# ### Попробуем с помощью нашей модели улучшить качество кластеризации текстов
# Если вы не понимаете, что такое кластеризация - почитать об этом можно по ссылке  - http://scikit-learn.org/stable/modules/clustering.html
#
# Если вам все равно кажется, что это сложно, и вы чувствуете себя более уверено в задаче классификации - вместо задачи кластеризации можно рассматривать задачу классификации - тогда вместо функции quality используйте roc-auc из библиотеки scikit learn, все остальные шаги предобработки и измерения признаков аналогичны

# %% [markdown]
# Мерить качество кластеризации будем следующим образом - измерим количество правильных попаданий категории в кластера

# %%
import itertools
def quality(preds, target, dataset):
    permutations = list(itertools.permutations([0, 1, 2]))
    scores = []
    for a, b, c in permutations:
        mapping = {2 : a, 1: b, 0: c}
        mapped_preds = [mapping[pred] for pred in preds]
        scores.append(float(sum(mapped_preds != target)) / len(target))
    return(1 - min(scores))

# %% [markdown]
# ### Пункт 1
#
# Кластеризуйте датасет с заданием признаков с помощью one hot encoding - посмотрите на результат

# %%
<Ваш код>

# %% [markdown]
# ### Пункт 2
# Далее кластеризуем тексты на векторах, полученных из модели, которую мы сами обучили

# %% [markdown]
# Напишем функцию, которая делает из предложения вектор - просто складывает вектора всех слов и усредняет. Если слов нет в словаре, то прибавляет нулевой вектор

# %%
def average_feature_vector(words, model):
    <Ваш код>
    return av_feat_vec

# %% [markdown]
# Применим функцию к нашим данным (уже нормализованным функцией normalize)

# %%
data_normalized_vectors = [average_feature_vector(sent, model) for sent in data_normalized]

# %% [markdown]
# Сожмем массив признаковс помощью tsne до нескольких компонент (попробуйте поварьировать число компонент)

# %%
tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
low_dim_vectors = tsne.fit_transform((data_normalized_vectors))

# %% [markdown]
# Примените алгоритм кластеризации (тут тоже есть где поэкспериментировать, можно K-means)

# %%
<Ваш код>

# %% [markdown]
# ### Пункт 3

# %% [markdown]
# Кластеризуем тексты на векторах, полученных из предобученной модели. Какой результат получился лучше? Почему?

# %%
<Ваш код>

# %% [markdown]
# ### Пункт 4 - для суперменов

# %% [markdown]
# Попробуйте получить аналогичные вектора и провети исследование на них с помощью fastq - неплохое введение - https://www.analyticsvidhya.com/blog/2017/07/word-representations-text-classification-using-fasttext-nlp-facebook/

# %%
<Ваш код>

# %% [markdown]
# ### Правила сдачи и критерии оценки:
#
# ##### Суперобязательная часть (40 % баллов)
#
# 1) Дописать функцию normalize, нормализующую тексты
#
# 2) Пункт 0
#
# ##### Обязательная часть (40 % баллов)
#
# 1) Пункт 1
#
# 2) Пункт 2
#
# 3) Пункт 3
#
# ##### Продвинутая часть (20 % баллов)
#
# 1) Любые самые смелые ваши идеи-эксперименты по тому, как можно улучшить качество моделей (пофильтровать какие-то части речи, редкие слова, использовать FastText)
#
# 2) Интересные, необычные, просто хорошо сформулированные выводы о вашей работе в отчете
#
# При проверке отчета будет обращаться внимание на ваш анализ и оригинальность подходов) Не нужно бояться экспериментировать и гуглить - машинное обучение ближе, чем кажется!
#
#
# ##### Как и куда сдавать:
#
# К jupiter- тетрадке нужно приложить текстовый отчет (желательно в word), в котором вы описываете, какие шаги выполняли, какое качество-графики получали и что это значит.
#
# Свой jupiter-noteebook вместе с отчетом присылать на почту savelievatanyya@gmail.com или в телеграмм http://telegram.me/tany_savelieva  со своим именем в качестве названия.
#
# Дедлайн - 19 ноября 9 утра
#
# ПО ВСЕМ ВОПРОСАМ, КАСАЮЩИМСЯ ЗАДАНИЯ (например, Таня, я не знаю, где смотреть, как кластеризуются-нормализуются тексты ) МОЖНО и НУЖНО писать мне на почту-в телеграмм - обещаю ответить в течение дня!
